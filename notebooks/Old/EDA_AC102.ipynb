# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

from pathlib import Path

from pandas import testing as tm

from sklearn.metrics import mean_absolute_error

import lib

# %%
pd.options.display.float_format = '{:,.2f}'.format

sns.set_theme(style="whitegrid", palette="muted")

sns.color_palette()
# Out:
# [(0.2823529411764706, 0.47058823529411764, 0.8156862745098039),
#  (0.9333333333333333, 0.5215686274509804, 0.2901960784313726),
#  (0.41568627450980394, 0.8, 0.39215686274509803),
#  (0.8392156862745098, 0.37254901960784315, 0.37254901960784315),
#  (0.5843137254901961, 0.4235294117647059, 0.7058823529411765),
#  (0.5490196078431373, 0.3803921568627451, 0.23529411764705882),
#  (0.8627450980392157, 0.49411764705882355, 0.7529411764705882),
#  (0.4745098039215686, 0.4745098039215686, 0.4745098039215686),
#  (0.8352941176470589, 0.7333333333333333, 0.403921568627451),
#  (0.5098039215686274, 0.7764705882352941, 0.8862745098039215)]

# %% [markdown]
# Функция поиска выбросов и диапазона

# %%
def plotMovingAverage(series: pd.DataFrame, window: int, plot_intervals: bool = False, scale: int = 1.96, plot_anomalies: bool = False) -> None:

    """
        series - dataframe with timeseries
        window - rolling window size 
        plot_intervals - show confidence intervals
        plot_anomalies - show anomalies 

    """
    rolling_mean = series.rolling(window=window).mean()

    plt.figure(figsize=(20,8))
    plt.title("Скользящее среднее\n размер окна = {}".format(window))
    plt.plot(rolling_mean, "r", label="Скользящее среднее")

    # Plot confidence intervals for smoothed values
    if plot_intervals:
        mae = mean_absolute_error(series[window:], rolling_mean[window:])
        deviation = np.std(series[window:] - rolling_mean[window:])
        lower_bond = rolling_mean - (mae + scale * deviation)
        upper_bond = rolling_mean + (mae + scale * deviation)
        plt.plot(upper_bond, "g--", label="Верхняя / нижняя граница")
        plt.plot(lower_bond, "g--")
        
        # Having the intervals, find abnormal values
        if plot_anomalies:
            anomalies = pd.DataFrame(index=series.index, columns=series.columns)
            anomalies[series<lower_bond] = series[series<lower_bond]
            anomalies[series>upper_bond] = series[series>upper_bond]
            plt.plot(anomalies, "ro", markersize=10)
        
    plt.plot(series[window:], label="Истинные значения")
    plt.legend(loc="upper left")
    plt.grid(True)

# %% [markdown]
# ## Анализ исходных данных по автоклаву AC102

# %% [markdown]
# ### Подготовка данных

# %% [markdown]
# Загрузим данные и заменим названия колонок.

# %%
WORK_DIR = "C:\\Users\\Laevskiy\Desktop\\05-22\\AC102"

# %%
filepath = Path(f'./{WORK_DIR}/df_total_ds_1h.zip')
df = pd.read_csv(filepath, index_col=0)
df.index.name = None
df.index = pd.to_datetime(df.index)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 24471 entries, 2019-01-07 08:00:00 to 2021-12-31 17:00:00
# Data columns (total 52 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   320PU102           24471 non-null  float64
#  1   320PU221           24471 non-null  float64
#  2   320RC102DIC02      24471 non-null  float64
#  3   330AC102FI06       24471 non-null  float64
#  4   330AC102FI07       24471 non-null  float64
#  5   330AC102FI08       24471 non-null  float64
#  6   330AC102FI09       24471 non-null  float64
#  7   330AC102FI10       24471 non-null  float64
#  8   330AC102FI51       24471 non-null  float64
#  9   330AC102FI52       24471 non-null  float64
#  10  330AC102FIC40      24471 non-null  float64
#  11  330AC102FICZ01     24471 non-null  float64
#  12  330AC102FICZ02     24471 non-null  float64
#  13  330AC102FICZ03     24471 non-null  float64
#  14  330AC102FICZ04     24471 non-null  float64
#  15  330AC102FICZ05     24471 non-null  float64
#  16  330AC102LICZ01     24471 non-null  float64
#  17  330AC102LICZ01.1   24471 non-null  float64
#  18  330AC102LICZ01.2   24471 non-null  float64
#  19  330AC102PI64       24471 non-null  float64
#  20  330AC102PI65       24471 non-null  float64
#  21  330AC102PIC63A     24471 non-null  float64
#  22  330AC102PIC63A.1   24471 non-null  float64
#  23  330AC102PIZ61      24471 non-null  float64
#  24  330AC102TIC01      24471 non-null  float64
#  25  330AC102TIC02      24471 non-null  float64
#  26  330AC102TIC03      24471 non-null  float64
#  27  330AC102TIC04      24471 non-null  float64
#  28  330AC102TIC05      24471 non-null  float64
#  29  330AC102TIZ61      24471 non-null  float64
#  30  330PT103PIZ01      24471 non-null  float64
#  31  330TK103LIC01      24471 non-null  float64
#  32  330TK103PI11       24471 non-null  float64
#  33  330TK103TI03       24471 non-null  float64
#  34  330TK103TIC02      24471 non-null  float64
#  35  330TK104LIC01      24471 non-null  float64
#  36  330TK104PI02       24471 non-null  float64
#  37  330TK104TIC02      24471 non-null  float64
#  38  380HX103FIC01      24471 non-null  float64
#  39  380HX103LIC01      24471 non-null  float64
#  40  380HX103PIC03      24471 non-null  float64
#  41  OXYGEN/OxyPurity   24471 non-null  float64
#  42  OXYGEN/OxyPurityB  24471 non-null  float64
#  43  Fe                 1100 non-null   float64
#  44  Stot               1220 non-null   float64
#  45  SO4                284 non-null    float64
#  46  As                 1105 non-null   float64
#  47  Corg               1210 non-null   float64
#  48  Ctot               1216 non-null   float64
#  49  Fe2+               24469 non-null  float64
#  50  D(S)               1273 non-null   float64
#  51  D(SL)              1160 non-null   float64
# dtypes: float64(52)
# memory usage: 9.9 MB

# %%
cols = [
    'Fel_1',
    'Fel_2',
    'D_SL',
    'QQ_C1',
    'QQ_C2',
    'QQ_C3',
    'QQ_C4',
    'QQ_C5',
    'O2_tot',
    'QQ_tot',
    'Sl_tot',
    'O2_C1',
    'O2_C2',
    'O2_C3',
    'O2_C4',
    'O2_C5',
    'AC_level',
    'AC_rbk_open',
    'AC_valve_open',
    'P_H2O',
    'P_O2',
    'P_tot',
    'P_valve',
    'P_tot_2',
    'T_C1',
    'T_C2',
    'T_C3',
    'T_C4',
    'T_C5',
    'T_abg',
    'P_O2_in',
    'FT1_level',
    'FT1_P',
    'FT1_T_in',
    'FT1_T',
    'FT2_level',
    'FT2_P',
    'FT2_T',
    'Cond_Q',
    'Cond_level',
    'Cond_valve',
    'O2_conc_1',
    'O2_conc_2',
    'Fe',
    'Stot',
    'SO4',
    'As',
    'Corg',
    'Ctot',
    'Fe2+',
    'D_S',
    'D_SL_H'
]

# %%
df.columns = cols

# %%
df.head()
# Out:
#                      Fel_1  Fel_2   D_SL  QQ_C1  QQ_C2  QQ_C3  QQ_C4  QQ_C5  \
# 2019-01-07 08:00:00   0.00   0.00 988.43  -0.01   0.02   0.00  -0.00   0.00
# 2019-01-07 09:00:00   0.00   0.00 988.43  -0.01   0.02   0.00  -0.00   0.00
# 2019-01-07 10:00:00   0.00   0.00 988.43  -0.01   0.02  -0.00  -0.00   0.00
# 2019-01-07 11:00:00   0.00   0.00 988.43  -0.01   0.02   0.00  -0.00   0.00
# 2019-01-07 12:00:00   0.00   0.00 988.43  -0.01   0.02   0.00  -0.00   0.00
#
#                       O2_tot  QQ_tot  ...  O2_conc_2  Fe  Stot  SO4  As  Corg  \
# 2019-01-07 08:00:00 4,950.00    0.01  ...       0.00 NaN   NaN  NaN NaN   NaN
# 2019-01-07 09:00:00 4,950.00    0.01  ...       0.00 NaN   NaN  NaN NaN   NaN
# 2019-01-07 10:00:00 4,950.00    0.01  ...       0.00 NaN   NaN  NaN NaN   NaN
# 2019-01-07 11:00:00 4,950.00    0.01  ...       0.00 NaN   NaN  NaN NaN   NaN
# 2019-01-07 12:00:00 4,950.00    0.01  ...       0.00 NaN   NaN  NaN NaN   NaN
#
#                      Ctot  Fe2+  D_S  D_SL_H
# 2019-01-07 08:00:00   NaN  0.00  NaN     NaN
# 2019-01-07 09:00:00   NaN  0.00  NaN     NaN
# 2019-01-07 10:00:00   NaN  0.00  NaN     NaN
# 2019-01-07 11:00:00   NaN  0.00  NaN     NaN
# 2019-01-07 12:00:00   NaN  0.00  NaN     NaN
#
# [5 rows x 52 columns]

# %%
df.describe().T
# Out:
#                   count     mean      std      min      25%      50%      75%  \
# Fel_1         24,471.00     8.89    16.45     0.00     0.00     0.00     0.00
# Fel_2         24,471.00    15.07    19.82     0.00     0.00     0.00    39.77
# D_SL          24,471.00 1,311.61   327.11   988.43 1,000.58 1,007.17 1,633.69
# QQ_C1         24,471.00     9.13     9.37    -0.02     0.00     7.92    16.89
# QQ_C2         24,471.00    17.12    15.60     0.00     0.03    24.77    31.28
# QQ_C3         24,471.00     9.26     8.47    -0.03    -0.01    13.16    17.15
# QQ_C4         24,471.00     2.75     3.00    -0.00    -0.00     1.72     4.74
# QQ_C5         24,471.00     0.79     1.05     0.00     0.00     0.45     1.15
# O2_tot        24,471.00 3,800.27 2,605.19    -6.51    -1.52 4,950.00 5,483.64
# QQ_tot        24,471.00    39.05    35.57    -0.01     0.03    56.39    70.01
# Sl_tot        24,471.00     0.00     0.04    -0.01     0.00     0.00     0.00
# O2_C1         24,471.00 1,482.61 1,049.21    -2.99    -0.98 1,800.00 2,215.51
# O2_C2         24,471.00 1,258.45   874.76    -1.25    -0.11 1,501.95 1,909.87
# O2_C3         24,471.00   674.82   470.38    -1.20    -0.15   900.79 1,000.00
# O2_C4         24,471.00   276.78   216.67    -4.97    -0.14   324.64   430.08
# O2_C5         24,471.00   107.61    86.05    -0.51    -0.11   136.95   156.19
# AC_level      24,471.00    63.64    19.58    -1.27    59.58    68.00    71.94
# AC_rbk_open   24,471.00    24.51    28.86     0.00     0.03    14.61    35.77
# AC_valve_open 24,471.00    27.60    31.91     0.00     0.00    16.60    38.88
# P_H2O         24,471.00    15.32    11.82   -23.71     0.00    23.54    24.76
# P_O2          24,471.00     4.22     3.25   -39.00     1.06     5.84     6.58
# P_tot         24,471.00    21.88    12.53    -0.05    11.72    30.00    30.00
# P_valve       24,471.00    35.25    35.78     0.00     8.17    21.71    53.16
# P_tot_2       24,471.00    18.89    14.17    -0.13     0.07    29.99    30.00
# T_C1          24,471.00   172.77    95.62     9.54    56.15   213.86   225.01
# T_C2          24,471.00   176.32    96.71    12.50    53.98   221.91   225.03
# T_C3          24,471.00   174.51    95.91    10.19    56.55   220.25   226.27
# T_C4          24,471.00   177.80    97.42    10.37    53.24   223.20   226.64
# T_C5          24,471.00   162.50    93.63     6.84    52.55   189.53   220.23
# T_abg         24,471.00   188.36    80.72    13.78   218.00   223.53   225.20
# P_O2_in       24,471.00    24.81    15.35    -0.09     0.01    34.06    34.37
# FT1_level     24,471.00    44.63    25.19    -1.27    32.80    43.57    50.00
# FT1_P         24,471.00     3.43     2.99    -0.24     0.16     5.37     6.13
# FT1_T_in      24,471.00   173.37    93.31    -0.28    41.54   207.26   216.39
# FT1_T         24,471.00   106.78    63.62    -2.49    30.03   146.35   164.94
# FT2_level     24,471.00    49.06    22.53    -1.27    39.99    42.19    50.00
# FT2_P         24,471.00     0.23     0.28    -0.05     0.04     0.10     0.30
# FT2_T         24,471.00    76.06    44.49    -2.49    31.55    86.59   101.67
# Cond_Q        24,471.00     7.90    15.54     0.00     0.00     0.03     0.06
# Cond_level    24,471.00    38.88    36.29    -1.27    -0.47    39.99    61.56
# Cond_valve    24,471.00    40.38    42.12     0.00     0.00    22.83   100.00
# O2_conc_1     24,471.00    77.71    39.99     0.00    95.00    99.60    99.90
# O2_conc_2     24,471.00    89.09    30.52     0.00    99.40    99.53    99.70
# Fe             1,100.00    27.70     3.61    11.27    25.50    27.90    29.86
# Stot           1,220.00    26.31     2.11    19.10    25.50    26.50    27.50
# SO4              284.00     0.42     1.62     0.05     0.13     0.19     0.33
# As             1,105.00     8.01     2.17     1.50     6.68     8.00     9.46
# Corg           1,210.00     0.61     2.06     0.11     0.44     0.52     0.60
# Ctot           1,216.00     1.03     0.23     0.35     0.91     1.01     1.13
# Fe2+          24,469.00     0.92     1.08     0.00     0.00     1.04     1.40
# D_S            1,273.00 3,861.97   164.61 3,400.00 3,800.00 3,900.00 4,000.00
# D_SL_H         1,160.00 1,651.35    67.68 1,098.33 1,604.00 1,635.00 1,703.00
#
#                     max
# Fel_1             50.26
# Fel_2             50.00
# D_SL           2,007.51
# QQ_C1             37.29
# QQ_C2             46.05
# QQ_C3             22.24
# QQ_C4             10.75
# QQ_C5              5.70
# O2_tot        11,000.00
# QQ_tot           106.35
# Sl_tot             5.41
# O2_C1          4,500.00
# O2_C2          3,000.00
# O2_C3          2,000.00
# O2_C4          1,000.00
# O2_C5            500.00
# AC_level          95.31
# AC_rbk_open      101.99
# AC_valve_open    100.00
# P_H2O             40.00
# P_O2              31.00
# P_tot             31.07
# P_valve          100.00
# P_tot_2           31.11
# T_C1             309.03
# T_C2             310.07
# T_C3             309.97
# T_C4             309.90
# T_C5             308.94
# T_abg            309.44
# P_O2_in           42.51
# FT1_level        103.13
# FT1_P              8.06
# FT1_T_in         309.55
# FT1_T            206.42
# FT2_level        103.05
# FT2_P              1.35
# FT2_T            206.42
# Cond_Q            65.30
# Cond_level       103.24
# Cond_valve       100.00
# O2_conc_1        100.00
# O2_conc_2        100.00
# Fe                47.19
# Stot              33.70
# SO4               24.40
# As                14.50
# Corg              71.00
# Ctot               2.15
# Fe2+              40.08
# D_S            4,300.00
# D_SL_H         1,830.00

# %% [markdown]
# Добавим некоторые новые признаки и уберем данные, за то время когда автоклав не работал.
#
# Уберем данные за время простоев автоклава
# Заполним данные ХА - df.loc[:, ['Fe']].interpolate(method='time') https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.interpolate.html

# %%
df[['Fel_1', 'Fel_2']].describe()
# Out:
#           Fel_1     Fel_2
# count 24,471.00 24,471.00
# mean       8.89     15.07
# std       16.45     19.82
# min        0.00      0.00
# 25%        0.00      0.00
# 50%        0.00      0.00
# 75%        0.00     39.77
# max       50.26     50.00

# %%
fig, ax = plt.subplots(figsize=(8, 5))

sns.histplot(df['Fel_1']+df['Fel_2'], ax=ax)

ax.set_xlabel('Производительность питающих насосов, 1/мин')
ax.set_ylabel('Число точек данных')

plt.show();

# %% [markdown]
# Для порога оценки работы питающих насосов возьмем значение 20 шагов, будем сравнивать сумму двух насосов.

# %%
df = df.assign(work = np.where((df['Fel_1'] + df['Fel_2'] >= 20), 1, 0))

# %%
df.work.value_counts()
# Out:
# 1    13657
# 0    10814
# Name: work, dtype: int64

# %% [markdown]
# Создадим новый массив данных убрав простои автоклава.

# %%
df_work = df.drop(df[df['work'] == 0].index).drop('work', axis=1)

# %%
fig, ax = plt.subplots(figsize=(8, 5))

sns.histplot(df_work['Fel_1']+df['Fel_2'], ax=ax)

ax.set_xlabel('Производительность питающих насосов, 1/мин')
ax.set_ylabel('Число точек данных')

plt.show();

# %% [markdown]
# Перейдем к пункту 2. Заполним недостающие строки по ХА.

# %%
int_cols = [
    'Fe',
    'Stot',
    'SO4',
    'As',
    'Corg',
    'Ctot',
    'D_S',
    'D_SL_H'
]

df_work[int_cols] = df_work.loc[:, int_cols].interpolate(method='time')

# %% [markdown]
# Сохраним полученный файл

# %%
comp = {
        'method': 'zip',
        'archive_name': 'out.csv'
    }

filepath = Path(f'./{WORK_DIR}/df_work_ds.zip')

df_work.to_csv(filepath, compression=comp)

# %% [markdown]
# Если мы не изменяем исходники, то просто загружаем файлик

# %%
df_work = pd.read_csv(f'{WORK_DIR}\df_work_ds.zip', index_col=0, parse_dates=True)

# %% [markdown]
# ## Чистка данных для моделирования

# %% [markdown]
# Нужно добавить следующие данные:
#    - Содержание твердого - C_S
#    - Расход пульпы - Q_SL
#    - Расход твердого - G_S
#    - Расход серного эквивалента - G_Seq
#
# Константы:
#    - Максимальная производительность насоса Feluwa 17,45 м³/ч
#    - Максимальное число шагов 51
#    - Мышьяк в СЭ - 0,371

# %%
FELUWA_MAX_Q = 17.45
FELUWA_MAX_N = 51
COEF_AS_SEQ = 0.371
D_WATER = 1000

# %%
fel_sum = df_work['Fel_1'] + df_work['Fel_2']

df_work = df_work.assign(Fel_sum = fel_sum.values)

# %%
df_work = df_work.assign(C_S = (df_work['D_S'] * D_WATER - df_work['D_SL_H'] * df_work['D_S']) / (df_work['D_SL_H'] * D_WATER - df_work['D_SL_H'] * df_work['D_S']) * 100)
df_work = df_work.assign(Q_SL = df_work['Fel_sum'] / FELUWA_MAX_N * FELUWA_MAX_Q)
df_work = df_work.assign(G_S = df_work['Q_SL'] * df_work['D_SL_H'] / 1000 * (df_work['C_S'] / 100))
df_work = df_work.assign(G_Seq = (COEF_AS_SEQ * df_work['As'] / 100 + df_work['Stot'] / 100) * df_work['G_S'])

# %% [markdown]
# В колонке SO4 много пропусков и нет доверия к анализу, уберем пока ее вообще.

# %%
df_work.drop('SO4', axis=1, inplace=True)

# %%
df_work.dropna(axis=0, inplace=True)

# %%
df_work.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 13648 entries, 2019-05-29 19:00:00 to 2021-12-11 01:00:00
# Data columns (total 56 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Fel_1          13648 non-null  float64
#  1   Fel_2          13648 non-null  float64
#  2   D_SL           13648 non-null  float64
#  3   QQ_C1          13648 non-null  float64
#  4   QQ_C2          13648 non-null  float64
#  5   QQ_C3          13648 non-null  float64
#  6   QQ_C4          13648 non-null  float64
#  7   QQ_C5          13648 non-null  float64
#  8   O2_tot         13648 non-null  float64
#  9   QQ_tot         13648 non-null  float64
#  10  Sl_tot         13648 non-null  float64
#  11  O2_C1          13648 non-null  float64
#  12  O2_C2          13648 non-null  float64
#  13  O2_C3          13648 non-null  float64
#  14  O2_C4          13648 non-null  float64
#  15  O2_C5          13648 non-null  float64
#  16  AC_level       13648 non-null  float64
#  17  AC_rbk_open    13648 non-null  float64
#  18  AC_valve_open  13648 non-null  float64
#  19  P_H2O          13648 non-null  float64
#  20  P_O2           13648 non-null  float64
#  21  P_tot          13648 non-null  float64
#  22  P_valve        13648 non-null  float64
#  23  P_tot_2        13648 non-null  float64
#  24  T_C1           13648 non-null  float64
#  25  T_C2           13648 non-null  float64
#  26  T_C3           13648 non-null  float64
#  27  T_C4           13648 non-null  float64
#  28  T_C5           13648 non-null  float64
#  29  T_abg          13648 non-null  float64
#  30  P_O2_in        13648 non-null  float64
#  31  FT1_level      13648 non-null  float64
#  32  FT1_P          13648 non-null  float64
#  33  FT1_T_in       13648 non-null  float64
#  34  FT1_T          13648 non-null  float64
#  35  FT2_level      13648 non-null  float64
#  36  FT2_P          13648 non-null  float64
#  37  FT2_T          13648 non-null  float64
#  38  Cond_Q         13648 non-null  float64
#  39  Cond_level     13648 non-null  float64
#  40  Cond_valve     13648 non-null  float64
#  41  O2_conc_1      13648 non-null  float64
#  42  O2_conc_2      13648 non-null  float64
#  43  Fe             13648 non-null  float64
#  44  Stot           13648 non-null  float64
#  45  As             13648 non-null  float64
#  46  Corg           13648 non-null  float64
#  47  Ctot           13648 non-null  float64
#  48  Fe2+           13648 non-null  float64
#  49  D_S            13648 non-null  float64
#  50  D_SL_H         13648 non-null  float64
#  51  Fel_sum        13648 non-null  float64
#  52  C_S            13648 non-null  float64
#  53  Q_SL           13648 non-null  float64
#  54  G_S            13648 non-null  float64
#  55  G_Seq          13648 non-null  float64
# dtypes: float64(56)
# memory usage: 5.9 MB

# Cond_valve    13,648.00    45.11  37.82     0.00     9.84    32.92    97.03
# O2_conc_1     13,648.00    79.79  38.76     0.00    95.00    99.80    99.90
# O2_conc_2     13,648.00    99.54   0.19    96.85    99.50    99.55    99.67
# Fe            13,648.00    28.05   3.62    11.27    25.60    28.20    30.73
# Stot          13,648.00    26.23   1.77    19.10    25.87    26.48    27.02
# As            13,648.00     7.92   1.97     1.50     6.48     8.16     9.18
# Corg          13,648.00     0.62   1.73     0.12     0.49     0.58     0.62
# Ctot          13,648.00     1.06   0.20     0.35     0.96     1.02     1.18
# Fe2+          13,648.00     1.29   1.15     0.00     0.96     1.40     1.55
# D_S           13,648.00 3,850.19 166.98 3,400.00 3,800.00 3,900.00 4,000.00
# D_SL_H        13,648.00 1,650.62  65.10 1,442.00 1,603.24 1,633.33 1,701.33
# Fel_sum       13,648.00    42.85   6.26    20.01    39.62    43.00    46.00
# C_S           13,648.00    53.15   3.08    42.16    50.71    52.50    55.61
# Q_SL          13,648.00    14.66   2.14     6.85    13.56    14.71    15.74
# G_S           13,648.00    12.84   1.94     5.57    11.47    12.87    14.15
# G_Seq         13,648.00     3.74   0.56     1.30     3.37     3.72     4.07
#
#                    max
# Fel_1            50.26
# Fel_2            50.00
# D_SL          2,007.51
# QQ_C1            37.29
# QQ_C2            46.05
# QQ_C3            22.24
# QQ_C4            10.75
# QQ_C5             5.70
# O2_tot        7,670.26
# QQ_tot          106.35
# Sl_tot            1.12
# O2_C1         3,091.71
# O2_C2         2,781.51
# O2_C3         1,434.33
# O2_C4           778.24
# O2_C5           321.17
# AC_level         84.34
# AC_rbk_open     101.99
# AC_valve_open   100.00
# P_H2O            28.16
# P_O2              9.26
# P_tot            31.07
# P_valve         100.00
# P_tot_2          31.06
# T_C1            230.87
# T_C2            231.84
# T_C3            233.63
# T_C4            232.83
# T_C5            233.85
# T_abg           309.43
# P_O2_in          35.97
# FT1_level       101.94
# FT1_P             8.06
# FT1_T_in        227.05
# FT1_T           175.53
# FT2_level       103.01
# FT2_P             1.35
# FT2_T           102.89
# Cond_Q           65.30
# Cond_level      103.24
# Cond_valve      100.00
# O2_conc_1       100.00
# O2_conc_2       100.00
# Fe               47.19
# Stot             33.70
# As               14.50
# Corg             71.00
# Ctot              2.02
# Fe2+             40.08
# D_S           4,300.00
# D_SL_H        1,830.00
# Fel_sum          79.95
# C_S              60.99
# Q_SL             27.36
# G_S              26.05
# G_Seq             7.82

# %% [markdown]
# ## Проведем анализ статистик признаков

# %% [markdown]
# ### Целевой признак -$Fe^{2+}$

# %%
df_work['Fe2+'].describe()
# Out:
# count   13,648.00
# mean         1.29
# std          1.15
# min          0.00
# 25%          0.96
# 50%          1.40
# 75%          1.55
# max         40.08
# Name: Fe2+, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(8, 10))

sns.boxplot(data=df_work, y='Fe2+', x=df_work.index.year);

ax.set_xlabel('Год')
ax.set_ylabel('Концентрация $Fe^{2+}$, г/л')

plt.show();

# %% [markdown]
# По всей видимости, точка со значением 74,4 одна и является выбросом. Найдем ее и посмотрим.

# %%
df_work[df_work['Fe2+']>35]
# Out:
#                      Fel_1  Fel_2     D_SL  QQ_C1  QQ_C2  QQ_C3  QQ_C4  QQ_C5  \
# 2021-03-01 18:00:00  31.76   0.00 1,000.58  17.35  27.12  17.16   4.51   0.76
#
#                       O2_tot  QQ_tot  ...  Corg  Ctot  Fe2+      D_S   D_SL_H  \
# 2021-03-01 18:00:00 4,984.66   66.89  ...  0.58  1.00 40.08 4,000.00 1,700.17
#
#                      Fel_sum   C_S  Q_SL   G_S  G_Seq
# 2021-03-01 18:00:00    31.76 54.91 10.87 10.15   3.14
#
# [1 rows x 56 columns]

# %%
df_work.loc['2021-03-01 12:00:00':'2021-03-01 23:00:00']
# Out:
#                      Fel_1  Fel_2     D_SL  QQ_C1  QQ_C2  QQ_C3  QQ_C4  QQ_C5  \
# 2021-03-01 12:00:00  32.07   0.00 1,000.58  17.34  27.12  17.16   4.51   0.82
# 2021-03-01 13:00:00  31.96   0.00 1,000.58  17.33  27.12  17.18   4.51   0.81
# 2021-03-01 14:00:00  31.86   0.00 1,000.58  17.35  27.13  17.18   4.51   0.81
# 2021-03-01 15:00:00  31.60   0.00 1,000.58  17.36  27.12  17.17   4.51   0.80
# 2021-03-01 16:00:00  31.60   0.00 1,000.57  17.36  27.12  17.17   4.51   0.78
# 2021-03-01 17:00:00  31.60   0.00 1,000.58  17.35  27.11  17.16   4.51   0.77
# 2021-03-01 18:00:00  31.76   0.00 1,000.58  17.35  27.12  17.16   4.51   0.76
# 2021-03-01 19:00:00  32.10   0.00 1,000.58  17.35  27.13  17.17   4.51   0.74
# 2021-03-01 20:00:00  32.27   0.00 1,000.58  17.35  27.13  17.09   4.51   0.73
# 2021-03-01 21:00:00  32.36   0.00 1,000.58  17.35  27.12  17.17   4.51   0.70
# 2021-03-01 22:00:00  32.42   0.00 1,000.58  17.34  27.12  17.17   4.51   0.70
# 2021-03-01 23:00:00  32.44   0.00 1,000.58  17.33  27.12  17.18   4.51   0.69
#
#                       O2_tot  QQ_tot  ...  Corg  Ctot  Fe2+      D_S   D_SL_H  \
# 2021-03-01 12:00:00 4,941.54   66.95  ...  0.60  1.02  2.18 4,000.00 1,689.17
# 2021-03-01 13:00:00 4,940.90   66.95  ...  0.60  1.02  2.06 4,000.00 1,691.00
# 2021-03-01 14:00:00 4,942.56   66.98  ...  0.60  1.02  2.17 4,000.00 1,692.83
# 2021-03-01 15:00:00 4,941.89   66.96  ...  0.59  1.01  2.13 4,000.00 1,694.67
# 2021-03-01 16:00:00 4,940.89   66.93  ...  0.59  1.01  2.18 4,000.00 1,696.50
# 2021-03-01 17:00:00 4,941.50   66.90  ...  0.59  1.01  1.99 4,000.00 1,698.33
# 2021-03-01 18:00:00 4,984.66   66.89  ...  0.58  1.00 40.08 4,000.00 1,700.17
# 2021-03-01 19:00:00 4,990.84   66.90  ...  0.58  1.00  7.68 4,000.00 1,702.00
# 2021-03-01 20:00:00 4,990.27   66.81  ...  0.58  1.00  1.83 4,000.00 1,700.33
# 2021-03-01 21:00:00 4,989.37   66.85  ...  0.58  1.00  2.35 4,000.00 1,698.67
# 2021-03-01 22:00:00 4,989.64   66.84  ...  0.57  1.00  1.85 4,000.00 1,697.00
# 2021-03-01 23:00:00 4,990.12   66.83  ...  0.57  1.00  1.89 4,000.00 1,695.33
#
#                      Fel_sum   C_S  Q_SL   G_S  G_Seq
# 2021-03-01 12:00:00    32.07 54.40 10.97 10.08   3.10
# 2021-03-01 13:00:00    31.96 54.48 10.93 10.07   3.10
# 2021-03-01 14:00:00    31.86 54.57 10.90 10.07   3.10
# 2021-03-01 15:00:00    31.60 54.66 10.81 10.01   3.09
# 2021-03-01 16:00:00    31.60 54.74 10.81 10.04   3.10
# 2021-03-01 17:00:00    31.60 54.82 10.81 10.07   3.11
# 2021-03-01 18:00:00    31.76 54.91 10.87 10.15   3.14
# 2021-03-01 19:00:00    32.10 54.99 10.98 10.28   3.18
# 2021-03-01 20:00:00    32.27 54.92 11.04 10.31   3.19
# 2021-03-01 21:00:00    32.36 54.84 11.07 10.31   3.19
# 2021-03-01 22:00:00    32.42 54.76 11.09 10.31   3.19
# 2021-03-01 23:00:00    32.44 54.69 11.10 10.29   3.19
#
# [12 rows x 56 columns]

# %% [markdown]
# Значения за 22 и 23 часа выпадают, уберем их в ручную, а затем интерполируем по соседним значениям. Нужна функция чистки значений.

# %%
df_work.loc['2021-03-01 18:00:00', 'Fe2+'] = np.NaN

# %%
df_work['Fe2+'].interpolate(method='time', inplace=True)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

sns.boxplot(data=df_work, y='Fe2+', x=df_work.index.year, ax=ax);
ax.set_ylim(0, 30)
# Out:
# (0.0, 30.0)

# %%
plotMovingAverage(df_work.loc[:, ['Fe2+']], window=2, plot_intervals=True, plot_anomalies=True, scale=3)

# %%
f, ax = plt.subplots(figsize=(15,5))

ax.plot(df_work['Fe2+'].values, label="Концентрация $Fe^{2+}$, г/л")

rolling_mean = df_work['Fe2+'].rolling(window=12).mean()
ax.plot(rolling_mean.values, c='red', label="Скользящее среднее")

f.tight_layout();

ax.set_ylabel('Концентрация $Fe^{2+}$, г/л')
ax.set_xlabel('Точки данных')

plt.legend()
plt.show();

# %%
df_work.loc[df_work['Fe2+'] > 10, :]
# Out:
#                      Fel_1  Fel_2     D_SL  QQ_C1  QQ_C2  QQ_C3  QQ_C4  QQ_C5  \
# 2020-02-28 16:00:00   0.00  49.51 1,001.16   5.08  16.47  11.21   4.78   0.93
# 2020-02-28 17:00:00   0.00  49.53 1,001.15   5.07  16.94  11.66   5.07   0.93
# 2020-03-09 20:00:00   0.00  48.95 1,001.15   5.42  26.78  19.21   9.28   2.95
# 2020-04-30 03:00:00  12.85  25.60 1,617.48  16.62  24.61   9.83   1.66   4.50
# 2020-05-26 22:00:00   0.00  36.73 1,519.37   9.27  31.18  15.53   3.17   1.10
# 2020-05-28 06:00:00   0.00  35.28 1,006.11   8.34  30.25  16.66   2.46   1.44
# 2020-05-28 07:00:00   0.00  27.01 1,006.71   8.38  30.49  16.65   2.85   1.56
# 2020-05-28 08:00:00   0.00  29.80 1,087.60   9.24  30.60  16.38   2.89   1.61
# 2021-11-30 11:00:00  28.98  29.00 1,001.13  17.95  27.77  16.63   4.44   0.62
#
#                       O2_tot  QQ_tot  ...  Corg  Ctot  Fe2+      D_S   D_SL_H  \
# 2019-05-29 19:00:00 3,483.99   42.48  ...  0.52  0.92  1.40 3,900.00 1,555.00
# 2019-05-29 20:00:00 3,835.29   47.42  ...  0.52  0.92  1.40 3,900.00 1,556.46
# 2019-05-30 16:00:00 3,933.21   41.42  ...  0.52  0.99  1.40 3,900.00 1,585.62
# 2019-05-30 17:00:00 2,818.14   29.65  ...  0.52  0.99  1.40 3,900.00 1,587.08
# 2019-05-30 18:00:00 3,201.38   32.32  ...  0.52  1.00  1.40 3,900.00 1,588.54
# ...                      ...     ...  ...   ...   ...   ...      ...      ...
# 2021-11-17 12:00:00 6,711.93   80.67  ...  0.30  0.77  1.40 3,500.00 1,688.83
# 2021-11-17 13:00:00 6,725.13   81.49  ...  0.29  0.76  1.40 3,500.00 1,689.00
# 2021-11-19 02:00:00 5,497.36   71.08  ...  0.34  0.85  1.40 3,500.00 1,676.58
# 2021-11-25 19:00:00 6,817.74   77.30  ...  0.38  0.93  1.40 3,500.00 1,662.00
# 2021-11-30 11:00:00 5,799.44   67.41  ...  0.32  0.83  1.40 3,500.00 1,570.00
#
#                      Fel_sum   C_S  Q_SL   G_S  G_Seq
# 2019-05-29 19:00:00    35.75 48.00 12.23  9.13   2.74
# 2019-05-29 20:00:00    32.23 48.08 11.03  8.25   2.48
# 2019-05-30 16:00:00    31.95 49.67 10.93  8.61   2.66
# 2019-05-30 17:00:00    21.03 49.75  7.20  5.68   1.76
# 2019-05-30 18:00:00    25.56 49.82  8.75  6.92   2.14
# ...                      ...   ...   ...   ...    ...
# 2021-11-17 12:00:00    47.00 57.10 16.08 15.51   4.33
# 2021-11-17 13:00:00    47.65 57.11 16.31 15.73   4.39
# 2021-11-19 02:00:00    41.58 56.50 14.23 13.48   3.65
# 2021-11-25 19:00:00    52.24 55.76 17.87 16.56   4.32
# 2021-11-30 11:00:00    57.98 50.83 19.84 15.83   3.90
#
# [2610 rows x 56 columns]

# %%
df_work.loc[df_work['Fe2+'] == 0, :]
df_work.loc[df_work['Fe2+'] == 0, :]= df.replace(0, np.nan)
df_work.loc[df_work['Fe2+'] == 0, :]= df.dropna(how='all', axis=0)

# %% [markdown]
# Оставшиеся выбросы не будем пока убирать, так как это могут быть технологические отклонения. Посмотрим как они будут описываться моделью.

# %%
less_one = df_work.loc[df_work['Fe2+'] <= 1, ['Fe2+']].count()
one_two = df_work.loc[(df_work['Fe2+'] > 1) & (df_work['Fe2+'] <= 2), ['Fe2+']].count()
more_two = df_work.loc[df_work['Fe2+'] > 2, ['Fe2+']].count()

print(less_one.values, one_two.values, more_two.values)
# Out:
# [2571] [9036] [857]

# %%
f, ax = plt.subplots(figsize=(8, 5))

sns.histplot(df_work['Fe2+'], ax=ax)

f.tight_layout();

ax.set_xlabel('Концентрация $Fe^{2+}$, г/л')
ax.set_ylabel('Число точек')

ax.set_ylim(0, 3000)
ax.set_xlim(0, 10)

plt.show();

# %% [markdown]
# ### Анализ состава исходного сырья

# %% [markdown]
# Выделим нужные колонки и посмотрим на распределения данных.
#
# В химическом анализе из баков питания могут быть выбросы или неправильные значения. В какие-то дни анализы могут быть неполными. Проверим по $Fe$ и $S_{tot}$.

# %%
df_work.loc[(df_work['Fe'] <= 10) & (df_work['Stot'] <= 10), ['Fe', 'Stot']].count()
# Out:
# Fe      0
# Stot    0
# dtype: int64

# %%
int_cols = [
    'Fe',
    'Stot',
    'As',
    'Corg',
    'Ctot'
]

df_work[int_cols].describe()
# Out:
#              Fe      Stot        As      Corg      Ctot
# count 12,467.00 12,467.00 12,467.00 12,467.00 12,467.00
# mean      28.06     26.19      7.96      0.63      1.07
# std        3.73      1.83      2.01      1.81      0.21
# min       11.27     19.10      1.50      0.12      0.35
# 25%       25.51     25.77      6.60      0.48      0.96
# 50%       28.38     26.45      8.12      0.58      1.04
# 75%       30.88     26.92      9.26      0.63      1.22
# max       47.19     33.70     14.50     71.00      2.02

# %% [markdown]
# Посмотрим на анализ органического углерода, судя по исходному распределению, там есть выбросы и/или ошибки. Проверим точки где органического углерода по анализу больше общего. Попробуем приравнять в таких точках значение органического углерода к общему.

# %%
df_work.loc[df_work['Corg'] > df_work['Ctot'], 'Corg'] = df_work.loc[df_work['Corg'] > df_work['Ctot'], 'Ctot']

# %%
df_work.loc[df_work['Corg'] > df_work['Ctot']].count().sum()
# Out:
# 0

# %%
df_work[int_cols].describe()
# Out:
#              Fe      Stot        As      Corg      Ctot
# count 12,467.00 12,467.00 12,467.00 12,467.00 12,467.00
# mean      28.06     26.19      7.96      0.55      1.07
# std        3.73      1.83      2.01      0.14      0.21
# min       11.27     19.10      1.50      0.12      0.35
# 25%       25.51     25.77      6.60      0.48      0.96
# 50%       28.38     26.45      8.12      0.58      1.04
# 75%       30.88     26.92      9.26      0.63      1.22
# max       47.19     33.70     14.50      1.71      2.02

# %%
f, ax = plt.subplots(5, 1, figsize=(15,30), sharex=True)

for i, col in enumerate(int_cols):
    ax[i].plot(df_work[col].values)
    ax[i].set_ylabel(f'Содержание {col}, %')

f.tight_layout();

ax[4].set_xlabel('Точки данных')

plt.show();

# %%
f, ax = plt.subplots(1, 5, figsize=(20,5))

for i, col in enumerate(int_cols):
    sns.boxplot(data=df_work, y=col, ax=ax[i])
    ax[i].set_ylabel(f'Содержание {col}, %')

f.tight_layout();

plt.show();

# %% [markdown]
# ## Анализ данных работы автоклава

# %% [markdown]
# Насосы питания

# %%
df[['Fel_1', 'Fel_2']].describe().T
# Out:
#           count  mean   std  min  25%  50%   75%   max
# Fel_1 24,471.00  8.89 16.45 0.00 0.00 0.00  0.00 50.26
# Fel_2 24,471.00 15.07 19.82 0.00 0.00 0.00 39.77 50.00

# %%
f, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=df_work, y='Fel_1', ax=axs[0], x=df_work.index.year);
sns.boxplot(data=df_work, y='Fel_2', ax=axs[1], x=df_work.index.year);

# %% [markdown]
# Достаточно часто используемый в стаистике график, описывающий распределение параметра. Предполагается что распределение параметра носит нормальных характер. Описание графика boxplot:
#
# <img src=".\working_data\Boxplot_vs_PDF.svg.png" width=30%>
#
# *источник картинки wikipedia*

# %%
f, ax = plt.subplots(figsize=(15,5))

plt.plot(df_work['Fel_1'].resample('H').first().fillna(value=np.nan))
plt.plot(df_work['Fel_2'].resample('H').first().fillna(value=np.nan))

ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%y'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
ax.set_ylim([0, 60])
ax.legend(['Насос 101', 'Насос 103'])

f.autofmt_xdate();
f.tight_layout();

ax.set_title('Производительность насосов по шагам')
ax.set_ylabel('Шаги поршня, 1/мин')

plt.show()

# %%
f, ax = plt.subplots(figsize=(15,5))

fel_sum = df_work['Fel_1'] + df_work['Fel_2']

plt.plot(fel_sum.resample('H').first().fillna(value=np.nan))

ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%y'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
ax.set_ylim([0, 90])

f.autofmt_xdate();
f.tight_layout();

ax.set_title('Производительность насосов по шагам суммарно')
ax.set_ylabel('Шаги поршня, 1/мин')

plt.show();

# %%
f, ax = plt.subplots(2, 1, figsize=(15,10), sharex=True)

ax[0].plot(df_work['Fel_1'].values)
ax[1].plot(df_work['Fel_2'].values)

f.tight_layout();

st = f.suptitle('Производительность насосов 1 и 2')
st.set_y(0.95)
f.subplots_adjust(top=0.9)

ax[0].set_ylabel('Шаги поршня, 1/мин')
ax[1].set_ylabel('Шаги поршня, 1/мин')

plt.show();

# %%
f, ax = plt.subplots(figsize=(15,5))

plt.plot(fel_sum.values)

ax.set_ylim([0, 90])

f.tight_layout();

ax.set_ylabel('Шаги поршня, 1/мин')
ax.set_xlabel('Точки данных')

plt.show();

# %% [markdown]
# ### Плотность пульпы

# %%
f, ax = plt.subplots(figsize=(15,5))

ax.scatter(df_work.index, df_work['D_SL'])

ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%y'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))

f.autofmt_xdate();
f.tight_layout();

ax.set_title('Плотность пульпы питания по плотномеру бака питания автоклава АС102')
ax.set_ylabel('Плотность, кг/м³')

plt.show();

# %%
f, ax = plt.subplots(figsize=(15,5))

ax.plot(df_work['D_SL'].values)

f.tight_layout();

ax.set_title('Плотность пульпы питания по плотномеру бака питания автоклава АС102')
ax.set_ylabel('Плотность, кг/м³')

plt.show()

# %%
plotMovingAverage(df_work.loc[:, ['D_SL']], window=36, plot_intervals=True, plot_anomalies=True)

# %% [markdown]
# Разброс параметра большой. Скорее всего нужно будет корректировать по результатам ручных замеров.

# %%
f, ax = plt.subplots(figsize=(15,5))

ax.plot(df_work['D_SL'].values, label="Плотномер (АСУТП)")
ax.plot(df_work['D_SL_H'].values, label="Ручной замер (ОТК)")

f.tight_layout();

ax.set_ylabel('Плотность пульпы бака питания AC102, кг/м³')
ax.set_xlabel('Точки данных')
ax.set_xlim(-500, 12000)

plt.legend()

plt.show();

# %%
f, axs = plt.subplots(1, 2, figsize=(8, 5), sharey=True)

sns.boxplot(data=df_work, y='D_SL', ax=axs[0])
axs[0].set_ylabel('Плотность пульпы, кг/м³')
axs[0].set_xlabel('Данные АСУТП')

sns.boxplot(data=df_work, y='D_SL_H', ax=axs[1])
axs[1].set_ylabel('')
axs[1].set_xlabel('Данные ручных замеров')

f.tight_layout()

plt.show()

# %%
f, ax = plt.subplots(figsize=(15,5))

ax.plot(df_work['D_S'].values)

f.tight_layout();


ax.set_ylabel('Плотность, кг/м³')
ax.set_xlabel('Точки данных')
ax.set_xlim(-500, 12000)

plt.show();

# %% [markdown]
# ### Расход воды по секциям и общий расход

# %%
QQ_cols = [
    'QQ_C1',
    'QQ_C2',
    'QQ_C3',
    'QQ_C4',
    'QQ_C5',
    'QQ_tot',
]

# %%
df_work[QQ_cols].describe().T
# Out:
#            count  mean   std   min   25%   50%   75%    max
# QQ_C1  13,647.00 16.30  6.40  0.00 12.18 16.29 20.46  37.29
# QQ_C2  13,648.00 30.56  5.24  0.03 27.74 30.54 33.98  46.05
# QQ_C3  13,648.00 16.56  2.79 -0.01 15.36 17.01 18.43  22.24
# QQ_C4  13,648.00  4.85  2.46 -0.00  3.21  4.56  6.48  10.75
# QQ_C5  13,648.00  1.39  1.06  0.00  0.62  1.05  1.91   5.70
# QQ_tot 13,648.00 69.66 12.09  0.02 62.50 68.34 76.69 106.35

# %%
f, ax = plt.subplots(5, 1, figsize=(15,25), sharex=True)

for i, col in enumerate(QQ_cols[:-1]):
    ax[i].plot(df_work[col].values)
    rolling_mean = df_work[col].rolling(window=12).mean()
    ax[i].plot(rolling_mean.values, c='red')
    ax[i].set_title(f'Подача воды в секцию {col[-2:]}')
    ax[i].set_ylabel('Расход воды, нм³/ч')

ax[4].set_xlim(-500, 12000)

f.tight_layout();

plt.show();

# %%
f, ax = plt.subplots(1, 5, figsize=(20, 5), sharey=True)

for i, col in enumerate(QQ_cols[:-1]):
    sns.boxplot(data=df_work, y=col, ax=ax[i])
    ax[i].set_ylabel('')
    ax[0].set_ylabel('Расход воды, нм³/ч')
    ax[i].set_xlabel(col[-2:])

f.tight_layout();

plt.show();

# %% [markdown]
# ### Температура

# %%
T_cols = [
    'T_C1',
    'T_C2',
    'T_C3',
    'T_C4',
    'T_C5',
    'T_abg'
]

# %%
df_work[T_cols].describe().T
# Out:
#           count   mean   std   min    25%    50%    75%    max
# T_C1  13,648.00 214.30 16.70 53.82 209.60 221.20 224.99 230.87
# T_C2  13,648.00 220.36  8.52 47.48 218.45 224.59 225.02 231.84
# T_C3  13,648.00 216.82 15.21 46.97 206.35 224.74 225.81 233.63
# T_C4  13,648.00 223.15  6.96 24.30 222.11 224.49 226.23 232.83
# T_C5  13,648.00 196.86 27.98 17.19 181.71 210.29 219.30 233.85
# T_abg 13,648.00 223.44  4.10 21.41 222.79 223.92 224.79 309.43

# %%
df_work['T_abg'].interpolate(method='time', inplace=True)

# %%
f, ax = plt.subplots(figsize=(15,5))

for col in T_cols:
    ax.plot(df_work[col].values)

f.tight_layout();

ax.set_title('Температура по секциям автоклава АС102')
ax.set_ylabel('Температура, °С')
ax.set_xlim(-500, 12000)

ax.legend(T_cols)

plt.show();

# %%
f, ax = plt.subplots(figsize=(15,5))

for col in T_cols[:-1]:
    ax.plot(df_work[col].resample('H').first().fillna(value=np.nan))

    ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%y'))
    ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))

f.autofmt_xdate();
f.tight_layout();

ax.set_title('Температура по секциям автоклава АС102')
ax.set_ylabel('Температура, °С')

ax.legend(T_cols[:-1])

plt.show();

# %% [markdown]
# Посмотрим где температура не отличается от 225 °С более чем на 10 градусов.

# %%
for col in T_cols[:-1]:
    delta = 5
    print(f'Для секции {col} значений с разницей меньше {delta} °С: {df_work.loc[(-df_work[col] + 225) <=delta, [col]].count()[0]}')
# Out:
# Для секции T_C1 значений с разницей меньше 5 °С: 7176
# Для секции T_C2 значений с разницей меньше 5 °С: 9650
# Для секции T_C3 значений с разницей меньше 5 °С: 9151
# Для секции T_C4 значений с разницей меньше 5 °С: 11396
# Для секции T_C5 значений с разницей меньше 5 °С: 3154

# %% [markdown]
# Получается что хуже всего температура измеряется в секциях 1 и 5. Там меньше половины точек больше 220 °С.

# %% [markdown]
# #### Взаимосвязь воды и температуры

# %% [markdown]
# Выберем те данные в которых температура по секциям была выше 220 °С. По всем секциям.

# %%
df_corr_T_QQ = df_work.loc[
    (df_work["T_C1"] >= 220)
    & (df_work["T_C2"] >= 220)
    & (df_work["T_C3"] >= 220)
    & (df_work["T_C4"] >= 220)
    & (df_work["T_C5"] >= 220),
    T_cols + QQ_cols[:-1],
]

# %%
df_corr_T_QQ.describe().T
# Out:
#          count   mean  std    min    25%    50%    75%    max
# T_C1  2,017.00 224.62 1.30 220.02 224.00 224.96 225.06 230.14
# T_C2  2,017.00 224.87 1.47 220.10 224.03 224.99 225.22 229.55
# T_C3  2,017.00 227.38 2.39 222.01 225.19 227.54 229.21 233.63
# T_C4  2,017.00 226.06 1.96 220.01 224.58 226.00 227.76 232.22
# T_C5  2,017.00 223.31 1.98 220.00 221.49 223.35 225.00 229.62
# T_abg 2,017.00 224.02 1.68 217.26 222.91 224.04 225.19 229.28
# QQ_C1 2,017.00  19.83 5.99   0.00  15.39  20.80  24.32  37.29
# QQ_C2 2,017.00  32.73 4.32  13.64  31.08  32.47  34.36  46.05
# QQ_C3 2,017.00  17.15 3.02   6.37  14.72  18.31  19.89  22.24
# QQ_C4 2,017.00   6.06 3.58  -0.00   2.39   7.09   9.90  10.75
# QQ_C5 2,017.00   1.08 0.72   0.00   0.63   0.94   1.39   5.70

# %%
corr = df_corr_T_QQ.corr()

mask = np.triu(np.ones_like(corr))

plt.figure(figsize=(10, 10))
sns.heatmap(corr, annot=True, cmap='Spectral', mask=mask);
plt.yticks(rotation=0)
plt.show()

# %%
f, ax = plt.subplots(figsize=(15,5))

for col in T_cols:
    ax.plot(df_corr_T_QQ[col].values)

f.tight_layout();

ax.set_title('Температура по секциям автоклава АС102')
ax.set_ylabel('Температура, °С')

ax.legend(T_cols)

plt.show();

# %% [markdown]
# Посмотрим распределение температур по секциям, для отобранных данных.

# %%
cdf = pd.concat(
    [
        df_corr_T_QQ[["T_C1"]].assign(S=1),
        df_corr_T_QQ[["T_C2"]].assign(S=2),
        df_corr_T_QQ[["T_C3"]].assign(S=3),
        df_corr_T_QQ[["T_C4"]].assign(S=4),
        df_corr_T_QQ[["T_C5"]].assign(S=5),
    ]
)

mdf = pd.melt(cdf, id_vars="S")

f, ax = plt.subplots(figsize=(15, 5))

ax = sns.boxplot(data=mdf, y="value", x="S")
ax.set_ylabel("Температура, °С")
ax.set_xlabel("Номер секции")
ax.set_ylim([215, 235])

plt.show()

# %% [markdown]
# А теперь посмотрим во времени, когда температурные датчики автоклава показывали корректные значения.

# %%
f, ax = plt.subplots(figsize=(15,5))

for col in T_cols[:-1]:
    ax.plot(df_corr_T_QQ[col].resample('H').first().fillna(value=np.nan))

    ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%y'))
    ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
    
f.autofmt_xdate();
f.tight_layout();

ax.set_title('Температура по секциям автоклава АС102')
ax.set_ylabel('Температура, °С')

ax.legend(T_cols[:-1])

plt.show();

# %% [markdown]
# ### Давление в автоклаве и расход кислорода

# %%
O2_cols = [
    'O2_C1',
    'O2_C2',
    'O2_C3',
    'O2_C4',
    'O2_C5',
    'O2_conc_1',
    'O2_conc_2',
]

P_cols = [
    'P_H2O',
    'P_O2',
    'P_tot',
    'P_valve'
]

# %% [markdown]
# Посмотрим общие статистики по подаче кислорода.

# %%
df_work[O2_cols].describe().T
# Out:
#               count     mean    std   min      25%      50%      75%      max
# O2_C1     13,648.00 2,151.90 375.83 -0.98 1,930.43 2,155.96 2,368.02 3,091.71
# O2_C2     13,648.00 1,838.56 324.69 -0.22 1,653.22 1,869.75 1,988.99 2,781.51
# O2_C3     13,648.00   931.40 147.91 -0.29   840.18   942.07 1,007.78 1,434.33
# O2_C4     13,648.00   355.56 111.77 -0.18   269.99   361.94   409.98   778.24
# O2_C5     13,648.00   146.71  40.22 -0.13   105.01   150.01   169.11   321.17
# O2_conc_1 13,642.00    79.82  38.73  0.00    95.00    99.80    99.90   100.00
# O2_conc_2 13,648.00    99.54   0.19 96.85    99.50    99.55    99.67   100.00

# %%
f, ax = plt.subplots(5, 1, figsize=(15,25), sharex=True)

for i, col in enumerate(O2_cols[:-2]):
    ax[i].plot(df_work[col].values)
    # rolling_mean = df_work[col].rolling(window=24).mean()
    # ax[i].plot(rolling_mean.values, c='red')
    ax[i].set_title(f'Подача кислорода в секцию {col[-2:]}')
    ax[i].set_ylabel('Расход кислорода, нм³/ч')

ax[4].set_xlim(-500, 12000)
f.tight_layout();

plt.show();

# %%
f, ax = plt.subplots(1, 5, figsize=(20, 5), sharey=True)

for i, col in enumerate(O2_cols[:-2]):
    sns.boxplot(data=df_work, y=col, ax=ax[i])
    ax[i].set_ylabel('')
    ax[0].set_ylabel('Расход кислорода, нм³/ч')
    ax[i].set_xlabel(col[-2:])

f.tight_layout();

plt.show();

# %% [markdown]
# Данные по чистоте кислорода использовать, скорее всего, нецелесообразно ввиду их практически постоянства.

# %%
f, ax = plt.subplots(figsize=(15,5))

plt.plot(df_work['O2_conc_1'].values)
plt.plot(df_work['O2_conc_2'].values)

ax.set_ylabel('Концентрация кислорода, %')

plt.show();

# %% [markdown]
# Давление P_tot и P_tot_2 целесообразно объединить в одно значение, взяв среднее.

# %%
df_work = df_work.assign(P_tot = df_work[['P_tot', 'P_tot_2']].mean(axis=1))

# %%
df_work.drop('P_tot_2', inplace=True, axis=1)

# %% [markdown]
# Посмотрим общие статистики по давлению

# %%
df_work[P_cols].describe().T
# Out:
#             count  mean   std   min   25%   50%   75%    max
# P_H2O   13,643.00 24.50  0.95 18.65 24.19 24.67 25.07  28.16
# P_O2    13,648.00  6.37  0.71  1.12  5.91  6.31  6.78   9.26
# P_tot   13,648.00 29.86  0.79  0.12 29.99 30.00 30.00  31.07
# P_valve 13,644.00 30.12 19.33  0.27 15.91 25.71 38.38 100.00

# %% [markdown]
# Скорее всего общее давление можно вообще удалить, так как это точно линейная комбинация давления паров воды и парциального давления кислорода.

# %%
df_work[df_work['P_H2O']<5]
# Out:
# Empty DataFrame
# Columns: [Fel_1, Fel_2, D_SL, QQ_C1, QQ_C2, QQ_C3, QQ_C4, QQ_C5, O2_tot, QQ_tot, Sl_tot, O2_C1, O2_C2, O2_C3, O2_C4, O2_C5, AC_level, AC_rbk_open, AC_valve_open, P_H2O, P_O2, P_tot, P_valve, T_C1, T_C2, T_C3, T_C4, T_C5, T_abg, P_O2_in, FT1_level, FT1_P, FT1_T_in, FT1_T, FT2_level, FT2_P, FT2_T, Cond_Q, Cond_level, Cond_valve, O2_conc_1, O2_conc_2, Fe, Stot, As, Corg, Ctot, Fe2+, D_S, D_SL_H, Fel_sum, C_S, Q_SL, G_S, G_Seq]
# Index: []
#
# [0 rows x 55 columns]

# %%
f, ax = plt.subplots(figsize=(15,5))

for col in ['P_H2O', 'P_O2']:
    ax.plot(df_work[col].values)

f.tight_layout();

ax.set_ylabel('Давление, бар')
ax.set_xlabel('Точки данных')
ax.set_xlim(-500, 12000)

ax.legend(['Давление паров воды', 'Давление кислорода'])

plt.show();

# %% [markdown]
# Посмотрим распределение давления кислорода и паров воды.

# %%
f, axs = plt.subplots(1, 2, figsize=(10, 5))

sns.boxplot(data=df_work, y="P_H2O", ax=axs[0], width=0.5)
sns.boxplot(data=df_work, y="P_O2", ax=axs[1], width=0.5)

axs[0].set_ylabel('Давление паров воды, бар')
axs[1].set_ylabel('Давление кислорода, бар')
# Out:
# Text(0, 0.5, 'Давление кислорода, бар')

# %%
f, ax = plt.subplots(figsize=(15,5))

ax.plot(df_work['P_valve'].values)

f.tight_layout();

ax.set_ylabel('Степень открытия, %')
ax.set_xlabel('Точки данных')
ax.set_xlim(-500, 12000)

plt.show();

# %% [markdown]
# А теперь посмотрим корреляции и для начала выберем нужные колонки с данными

# %%
corr_cols = [
    'O2_C1',
    'O2_C2',
    'O2_C3',
    'O2_C4',
    'O2_C5',
    'P_H2O',
    'P_O2',
    'P_valve',
    'QQ_C1',
    'QQ_C2',
    'QQ_C3',
    'QQ_C4',
    'QQ_C5',
    'Fe',
    'Stot',
    'As',
    'Corg',
    'Ctot',
    'Fe2+'
]

# %%
corr = df_work[corr_cols].corr()

mask = np.triu(np.ones_like(corr))

plt.figure(figsize=(15, 15))
sns.heatmap(corr, annot=True, cmap="Spectral", mask=mask);
plt.yticks(rotation=0)
plt.show();

# %% [markdown]
# ### Уровень в автоклаве и клапан сброса

# %%
l_cols = [
    'AC_level',
    'AC_valve_open'
]

# %%
df_work[l_cols].describe()
# Out:
#        AC_level  AC_valve_open
# count 13,648.00      13,647.00
# mean      67.45          31.60
# std        3.46          24.30
# min       52.46           0.00
# 25%       67.72          13.41
# 50%       68.00          29.31
# 75%       68.99          38.75
# max       84.34         100.00

# %%
f, ax = plt.subplots(figsize=(15,5))

for col in l_cols:
    ax.plot(df_work[col].values)

rolling_mean = df_work['AC_valve_open'].rolling(window=24).mean()
ax.plot(rolling_mean.values, c='green')

f.tight_layout();

ax.set_title('Уровень в АС / Степень открытия клапана')
ax.set_ylabel('Параметр, %')
ax.set_ylim([0, 100])
ax.set_xlim(-500, 12000)

ax.legend(l_cols + ['Скользящее среднее'])

plt.show();

# %% [markdown]
# ## Сохраним итоговый файл для дальнейших расчётов¶

# %%
df_work[df_work < 0] = 0

# %%
df_work.describe().T
# Out:
#                   count     mean    std      min      25%      50%      75%  \
# Fel_1         12,719.00    17.05  19.52     0.00     0.00     0.00    37.53
# Fel_2         13,471.00    27.31  19.48     0.00     0.00    37.80    43.00
# D_SL          13,648.00 1,516.36 265.17 1,000.29 1,587.37 1,622.90 1,663.52
# QQ_C1         13,647.00    16.30   6.40     0.00    12.18    16.29    20.46
# QQ_C2         13,648.00    30.56   5.24     0.03    27.74    30.54    33.98
# QQ_C3         13,648.00    16.56   2.79     0.00    15.36    17.01    18.43
# QQ_C4         13,648.00     4.85   2.46     0.00     3.21     4.56     6.48
# QQ_C5         13,648.00     1.39   1.06     0.00     0.62     1.05     1.91
# O2_tot        13,648.00 5,424.13 775.93     0.00 4,999.08 5,404.04 5,778.33
# QQ_tot        13,648.00    69.66  12.09     0.02    62.50    68.34    76.69
# Sl_tot        12,820.00     0.00   0.01     0.00     0.00     0.00     0.00
# O2_C1         13,648.00 2,151.90 375.83     0.00 1,930.43 2,155.96 2,368.02
# O2_C2         13,648.00 1,838.56 324.69     0.00 1,653.22 1,869.75 1,988.99
# O2_C3         13,648.00   931.40 147.91     0.00   840.18   942.07 1,007.78
# O2_C4         13,648.00   355.56 111.77     0.00   269.99   361.94   409.98
# O2_C5         13,648.00   146.71  40.22     0.00   105.01   150.01   169.11
# AC_level      13,648.00    67.45   3.46    52.46    67.72    68.00    68.99
# AC_rbk_open   13,648.00    30.32  20.80     0.03    14.36    29.54    38.28
# AC_valve_open 13,647.00    31.60  24.30     0.00    13.41    29.31    38.75
# P_H2O         13,643.00    24.50   0.95    18.65    24.19    24.67    25.07
# P_O2          13,648.00     6.37   0.71     1.12     5.91     6.31     6.78
# P_tot         13,648.00    29.86   0.79     0.12    29.99    30.00    30.00
# P_valve       13,644.00    30.12  19.33     0.27    15.91    25.71    38.38
# T_C1          13,648.00   214.30  16.70    53.82   209.60   221.20   224.99
# T_C2          13,648.00   220.36   8.52    47.48   218.45   224.59   225.02
# T_C3          13,648.00   216.82  15.21    46.97   206.35   224.74   225.81
# T_C4          13,648.00   223.15   6.96    24.30   222.11   224.49   226.23
# T_C5          13,648.00   196.86  27.98    17.19   181.71   210.29   219.30
# T_abg         13,648.00   223.44   4.10    21.41   222.79   223.92   224.79
# P_O2_in       13,648.00    34.15   0.39     0.00    34.00    34.13    34.31
# FT1_level     13,648.00    36.84  11.82     0.00    31.27    39.48    45.23
# FT1_P         13,648.00     6.04   0.65     0.10     5.86     6.13     6.37
# FT1_T_in      13,648.00   206.60  12.70    36.51   202.87   211.26   215.15
# FT1_T         13,648.00   157.91  12.01    31.93   152.03   162.62   166.05
# FT2_level     13,648.00    43.28   8.49    14.93    39.98    40.01    45.00
# FT2_P         13,647.00     0.36   0.31     0.01     0.10     0.25     0.58
# FT2_T         13,648.00    94.15  11.98    23.61    87.67   100.99   101.93
# Cond_Q        13,545.00    14.25  18.60     0.00     0.03     0.03    32.08
# Cond_level    13,648.00    37.83  27.12     0.00    18.90    40.00    45.63
# Cond_valve    13,573.00    45.36  37.77     0.00    10.00    33.11    97.45
# O2_conc_1     13,642.00    79.82  38.73     0.00    95.00    99.80    99.90
# O2_conc_2     13,648.00    99.54   0.19    96.85    99.50    99.55    99.67
# Fe            12,467.00    28.06   3.73    11.27    25.51    28.38    30.88
# Stot          12,467.00    26.19   1.83    19.10    25.77    26.45    26.92
# As            12,467.00     7.96   2.01     1.50     6.60     8.12     9.26
# Corg          12,467.00     0.55   0.14     0.12     0.48     0.58     0.63
# Ctot          12,467.00     1.07   0.21     0.35     0.96     1.04     1.22
# Fe2+          12,464.00     1.41   1.08     0.15     1.04     1.40     1.59
# D_S           12,560.00 3,845.75 168.44 3,400.00 3,800.00 3,900.00 3,970.00
# D_SL_H        12,560.00 1,651.05  65.44 1,442.00 1,603.22 1,634.28 1,700.83
# Fel_sum       12,464.00    42.65   6.38    20.01    39.34    42.44    46.00
# C_S           12,464.00    53.20   3.07    42.16    50.80    52.54    55.58
# Q_SL          12,464.00    14.59   2.18     6.85    13.46    14.52    15.74
# G_S           12,464.00    12.80   1.98     5.57    11.37    12.80    14.13
# G_Seq         12,464.00     3.72   0.57     1.30     3.34     3.68     4.04
#
#                    max
# Fel_1            50.26
# Fel_2            50.00
# D_SL          2,007.51
# QQ_C1            37.29
# QQ_C2            46.05
# QQ_C3            22.24
# QQ_C4            10.75
# QQ_C5             5.70
# O2_tot        7,670.26
# QQ_tot          106.35
# Sl_tot            1.12
# O2_C1         3,091.71
# O2_C2         2,781.51
# O2_C3         1,434.33
# O2_C4           778.24
# O2_C5           321.17
# AC_level         84.34
# AC_rbk_open     101.99
# AC_valve_open   100.00
# P_H2O            28.16
# P_O2              9.26
# P_tot            31.07
# P_valve         100.00
# T_C1            230.87
# T_C2            231.84
# T_C3            233.63
# T_C4            232.83
# T_C5            233.85
# T_abg           309.43
# P_O2_in          35.97
# FT1_level       101.94
# FT1_P             8.06
# FT1_T_in        227.05
# FT1_T           175.53
# FT2_level       103.01
# FT2_P             1.35
# FT2_T           102.89
# Cond_Q           65.30
# Cond_level      103.24
# Cond_valve      100.00
# O2_conc_1       100.00
# O2_conc_2       100.00
# Fe               47.19
# Stot             33.70
# As               14.50
# Corg              1.71
# Ctot              2.02
# Fe2+             31.40
# D_S           4,300.00
# D_SL_H        1,830.00
# Fel_sum          79.95
# C_S              60.99
# Q_SL             27.36
# G_S              26.05
# G_Seq             7.82

# %%
comp = {
        'method': 'zip',
        'archive_name': 'out.csv'
    }

filepath = Path(f'./{WORK_DIR}/df_work_ds_final.zip')

df_work.to_csv(filepath, compression=comp)
