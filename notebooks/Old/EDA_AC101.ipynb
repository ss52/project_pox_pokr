# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

from pathlib import Path

from pandas import testing as tm

from sklearn.metrics import mean_absolute_error

import lib
import src

import os
from dotenv import load_dotenv

# %%
pd.options.display.float_format = '{:,.2f}'.format

# sns.set_theme(style="whitegrid", palette="muted")

sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %% [markdown]
# # Анализ исходных данных по автоклаву AC101

# %% [markdown]
# ## Подготовка данных
#
# Загрузим данные и заменим названия колонок.

# %%
load_dotenv(override=True)

WORK_DIR = os.getenv("RAW_DIR")
FILE_NAME = os.getenv("RAW_DF_NAME")
AC = "101"

# %%
filepath = Path(f'..\\..\\{WORK_DIR}\\{FILE_NAME}{AC}.zip')
df = pd.read_csv(filepath, index_col=0)
df.index.name = None
df.index = pd.to_datetime(df.index)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 23898 entries, 2019-01-01 07:00:00 to 2021-12-01 19:00:00
# Data columns (total 52 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   320PU101           23898 non-null  float64
#  1   320PU103           23898 non-null  float64
#  2   320RC101DIC02      23898 non-null  float64
#  3   330AC101FI06       23898 non-null  float64
#  4   330AC101FI07       23898 non-null  float64
#  5   330AC101FI08       23898 non-null  float64
#  6   330AC101FI09       23898 non-null  float64
#  7   330AC101FI10       23898 non-null  float64
#  8   330AC101FI51       23898 non-null  float64
#  9   330AC101FI52       23898 non-null  float64
#  10  330AC101FIC40      23898 non-null  float64
#  11  330AC101FICZ01     23898 non-null  float64
#  12  330AC101FICZ02     23898 non-null  float64
#  13  330AC101FICZ03     23898 non-null  float64
#  14  330AC101FICZ04     23898 non-null  float64
#  15  330AC101FICZ05     23898 non-null  float64
#  16  330AC101LICZ01     23898 non-null  float64
#  17  330AC101LICZ01.1   23898 non-null  float64
#  18  330AC101LICZ01.2   23898 non-null  float64
#  19  330AC101PI64       23898 non-null  float64
#  20  330AC101PI65       23898 non-null  float64
#  21  330AC101PIC63A     23898 non-null  float64
#  22  330AC101PIC63A.1   23898 non-null  float64
#  23  330AC101PIZ61      23898 non-null  float64
#  24  330AC101TIC01      23898 non-null  float64
#  25  330AC101TIC02      23898 non-null  float64
#  26  330AC101TIC03      23898 non-null  float64
#  27  330AC101TIC04      23898 non-null  float64
#  28  330AC101TIC05      23898 non-null  float64
#  29  330AC101TIZ61      23898 non-null  float64
#  30  330PT101PIZ01      23898 non-null  float64
#  31  330TK101LIC01      23898 non-null  float64
#  32  330TK101PI11       23898 non-null  float64
#  33  330TK101TI03       23898 non-null  float64
#  34  330TK101TIC02      23898 non-null  float64
#  35  330TK102LIC01      23898 non-null  float64
#  36  330TK102PI02       23898 non-null  float64
#  37  330TK102TIC02      23898 non-null  float64
#  38  380HX101FIC01      23898 non-null  float64
#  39  380HX101LIC01      23898 non-null  float64
#  40  380HX101PIC03      23898 non-null  float64
#  41   OXYGEN/OxyPurity  23898 non-null  float64
#  42  OXYGEN/OxyPurityB  23898 non-null  float64
#  43  Fe                 1050 non-null   float64
#  44  Stot               1169 non-null   float64
#  45  SO4                284 non-null    float64
#  46  As                 1054 non-null   float64
#  47  Corg               1160 non-null   float64
#  48  Ctot               1165 non-null   float64
#  49  Fe2+               23896 non-null  float64
#  50  D(S)               1543 non-null   float64
#  51  D(SL)              1003 non-null   float64
# dtypes: float64(52)
# memory usage: 9.7 MB

# %%
cols = [
    'Fel_1',
    'Fel_2',
    'D_SL',
    'QQ_C1',
    'QQ_C2',
    'QQ_C3',
    'QQ_C4',
    'QQ_C5',
    'O2_tot',
    'QQ_tot',
    'Sl_tot',
    'O2_C1',
    'O2_C2',
    'O2_C3',
    'O2_C4',
    'O2_C5',
    'AC_level',
    'AC_rbk_open',
    'AC_valve_open',
    'P_H2O',
    'P_O2',
    'P_tot',
    'P_valve',
    'P_tot_2',
    'T_C1',
    'T_C2',
    'T_C3',
    'T_C4',
    'T_C5',
    'T_abg',
    'P_O2_in',
    'FT1_level',
    'FT1_P',
    'FT1_T_in',
    'FT1_T',
    'FT2_level',
    'FT2_P',
    'FT2_T',
    'Cond_Q',
    'Cond_level',
    'Cond_valve',
    'O2_conc_1',
    'O2_conc_2',
    'Fe',
    'Stot',
    'SO4',
    'As',
    'Corg',
    'Ctot',
    'Fe2+',
    'D_S',
    'D_SL_H'
]

# %%
df.columns = cols

# %%
df.head()
# Out:
#                      Fel_1  Fel_2     D_SL  QQ_C1  QQ_C2  QQ_C3  QQ_C4  QQ_C5  \
# 2019-01-01 07:00:00  39.40   0.00 1,650.62  19.00  20.32  15.47   1.91   0.00
# 2019-01-01 08:00:00  39.40   0.00 1,651.31  18.98  20.53  15.50   2.11   0.00
# 2019-01-01 09:00:00  39.40   0.00 1,653.45  19.09  20.34  15.71   2.31   0.03
# 2019-01-01 10:00:00  39.38   0.00 1,649.85  18.95  20.51  15.41   1.93   0.08
# 2019-01-01 11:00:00  39.41   0.00 1,652.31  18.86  20.23  15.53   2.21   0.06
#
#                       O2_tot  QQ_tot  ...  O2_conc_2  Fe  Stot  SO4  As  Corg  \
# 2019-01-01 07:00:00 5,308.46   56.70  ...       0.00 NaN   NaN  NaN NaN   NaN
# 2019-01-01 08:00:00 5,308.08   57.12  ...       0.00 NaN   NaN  NaN NaN   NaN
# 2019-01-01 09:00:00 5,307.43   57.47  ...       0.00 NaN   NaN  NaN NaN   NaN
# 2019-01-01 10:00:00 5,310.11   56.89  ...       0.00 NaN   NaN  NaN NaN   NaN
# 2019-01-01 11:00:00 5,313.76   56.88  ...       0.00 NaN   NaN  NaN NaN   NaN
#
#                      Ctot  Fe2+      D_S   D_SL_H
# 2019-01-01 07:00:00   NaN  1.45 3,900.00 1,600.00
# 2019-01-01 08:00:00   NaN  1.11      NaN      NaN
# 2019-01-01 09:00:00   NaN  1.11      NaN      NaN
# 2019-01-01 10:00:00   NaN  1.23      NaN      NaN
# 2019-01-01 11:00:00   NaN  1.23      NaN      NaN
#
# [5 rows x 52 columns]

# %%
df.describe().T
# Out:
#                   count     mean      std    min      25%      50%      75%  \
# Fel_1         23,898.00    14.16    18.85   0.00     0.00     0.00    34.20
# Fel_2         23,898.00     8.27    15.42   0.00     0.00     0.00     0.00
# D_SL          23,898.00 1,339.63   341.38 988.43 1,001.45 1,354.93 1,657.93
# QQ_C1         23,898.00     8.88    10.35  -0.05    -0.00     0.03    19.36
# QQ_C2         23,898.00    14.64    15.55   0.00     0.03     2.58    30.33
# QQ_C3         23,898.00     7.93     8.47   0.00     0.01     1.01    17.19
# QQ_C4         23,898.00     2.67     3.12   0.00     0.00     0.00     5.25
# QQ_C5         23,898.00     1.03     1.54  -0.00    -0.00     0.02     1.93
# O2_tot        23,898.00 2,772.93 2,873.57 -22.42    -2.48     8.73 5,442.15
# QQ_tot        23,898.00    35.15    37.26   0.00     0.04     3.55    73.70
# Sl_tot        23,898.00     1.29     4.47  -0.01     0.00     0.00     0.00
# O2_C1         23,898.00 1,087.13 1,149.23  -9.13    -1.30     2.92 2,159.43
# O2_C2         23,898.00   945.73   998.12 -15.90    -0.43    -0.07 1,910.67
# O2_C3         23,898.00   481.96   515.91  -1.29    -0.59    -0.45   962.90
# O2_C4         23,898.00   183.63   204.19  -0.50    -0.04     0.00   379.03
# O2_C5         23,898.00    74.47    83.93  -0.36    -0.11    -0.10   156.97
# AC_level      23,898.00    66.83    21.35  -1.29    65.98    67.55    81.15
# AC_rbk_open   23,898.00    19.80    27.14  -1.19     3.50     8.65    25.74
# AC_valve_open 23,898.00    18.92    28.17   0.00     0.00     7.01    25.00
# P_H2O         23,898.00    16.72    10.59   0.00     0.00    22.19    24.76
# P_O2          23,898.00     4.92     3.28 -22.18     1.17     6.02     6.96
# P_tot         23,898.00    20.65    12.71  -0.08     0.31    27.00    30.00
# P_valve       23,898.00    61.87    35.51   0.00    28.46    62.41   100.00
# P_tot_2       23,898.00    21.13    12.62  -0.15     7.26    28.20    29.99
# T_C1          23,898.00   150.94   105.59  -3.73    26.00   216.39   225.00
# T_C2          23,898.00   151.76   105.81  -3.82    25.84   215.87   225.00
# T_C3          23,898.00   169.82   101.64  -3.82    42.76   201.48   225.34
# T_C4          23,898.00   173.50   104.24  13.18    39.45   220.00   227.10
# T_C5          23,898.00   144.31   102.74   0.00    25.29   186.14   219.84
# T_abg         23,898.00   167.14    85.50   7.66    34.38   217.71   224.00
# P_O2_in       23,898.00    21.41    16.48  -0.08     0.00    33.86    34.18
# FT1_level     23,898.00    60.82    32.48  -1.24    43.04    50.61   101.59
# FT1_P         23,898.00     3.04     3.10  -0.25     0.04     0.40     6.19
# FT1_T_in      23,898.00   107.82    78.94   9.80    29.53    98.60   182.69
# FT1_T         23,898.00    97.21    68.38   0.00    23.72    99.97   165.74
# FT2_level     23,898.00    55.92    34.43  -1.30    39.95    41.00    99.76
# FT2_P         23,898.00     0.09     0.13  -0.06    -0.00     0.06     0.14
# FT2_T         23,898.00    64.33    38.23   3.99    23.96    61.41   101.75
# Cond_Q        23,898.00     8.17    16.06  -0.00     0.00     0.00     0.02
# Cond_level    23,898.00    55.12    36.90  -1.24    12.09    45.00    99.83
# Cond_valve    23,898.00     2.93     3.09  -0.44     0.01     0.48     6.00
# O2_conc_1     23,898.00    76.57    40.72   0.00    95.00    97.70    99.90
# O2_conc_2     23,898.00    88.23    31.59   0.00    99.40    99.51    99.70
# Fe             1,050.00    27.93     3.49  11.27    25.89    28.12    29.98
# Stot           1,169.00    26.44     2.03  19.10    25.70    26.50    27.50
# SO4              284.00     0.42     1.62   0.05     0.13     0.19     0.33
# As             1,054.00     8.19     2.07   1.50     6.85     8.11     9.53
# Corg           1,160.00     0.62     2.10   0.12     0.45     0.53     0.61
# Ctot           1,165.00     1.03     0.23   0.35     0.91     1.01     1.14
# Fe2+          23,896.00     1.25     0.82   0.00     0.93     1.12     1.46
# D_S            1,543.00 3,876.44   151.06  95.98 3,890.00 3,900.00 3,900.00
# D_SL_H         1,003.00 1,655.35   104.28   0.00 1,614.00 1,665.00 1,709.00
#
#                    max
# Fel_1            50.51
# Fel_2            49.94
# D_SL          2,035.59
# QQ_C1            31.43
# QQ_C2            44.38
# QQ_C3            21.73
# QQ_C4            11.89
# QQ_C5             7.64
# O2_tot        7,551.90
# QQ_tot           97.32
# Sl_tot           25.74
# O2_C1         4,500.00
# O2_C2         2,705.14
# O2_C3         1,598.46
# O2_C4           850.34
# O2_C5           500.00
# AC_level        102.82
# AC_rbk_open     103.27
# AC_valve_open   100.00
# P_H2O            27.47
# P_O2             23.66
# P_tot            31.28
# P_valve         100.00
# P_tot_2          36.15
# T_C1            309.98
# T_C2            309.20
# T_C3            309.03
# T_C4            309.03
# T_C5            309.69
# T_abg           230.02
# P_O2_in          39.29
# FT1_level       103.01
# FT1_P             9.53
# FT1_T_in        308.59
# FT1_T           206.42
# FT2_level       102.58
# FT2_P             1.14
# FT2_T           206.02
# Cond_Q           70.12
# Cond_level      103.30
# Cond_valve        9.54
# O2_conc_1       100.00
# O2_conc_2       100.00
# Fe               47.19
# Stot             33.70
# SO4              24.40
# As               14.50
# Corg             71.00
# Ctot              2.15
# Fe2+             74.40
# D_S           4,300.00
# D_SL_H        1,828.00

# %% [markdown]
# Добавим некоторые новые признаки и уберем данные, за то время когда автоклав не работал.
#
# 1. Уберем данные за время простоев автоклава
# 2. Заполним данные ХА - ```df.loc[:, ['Fe']].interpolate(method='time')```
#     https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.interpolate.html

# %%
df[['Fel_1', 'Fel_2']].describe()
# Out:
#           Fel_1     Fel_2
# count 23,898.00 23,898.00
# mean      14.16      8.27
# std       18.85     15.42
# min        0.00      0.00
# 25%        0.00      0.00
# 50%        0.00      0.00
# 75%       34.20      0.00
# max       50.51     49.94

# %%
fig, ax = plt.subplots(figsize=(8, 5))

sns.histplot(df['Fel_1']+df['Fel_2'], ax=ax)

ax.set_xlabel('Производительность питающих насосов, 1/мин')
ax.set_ylabel('Число точек данных')

plt.show();

# %% [markdown]
# Для порога оценки работы питающих насосов возьмем значение 20 шагов, будем сравнивать сумму двух насосов.

# %%
df = df.assign(work = np.where((df['Fel_1'] + df['Fel_2'] >= 20), 1, 0))

# %%
df.work.value_counts()
# Out:
# 0    12393
# 1    11505
# Name: work, dtype: int64

# %% [markdown]
# Создадим новый массив данных убрав простои автоклава.

# %%
df_work = df.drop(df[df['work'] == 0].index).drop('work', axis=1)

# %%
fig, ax = plt.subplots(figsize=(8, 5))

sns.histplot(df_work['Fel_1']+df['Fel_2'], ax=ax)

ax.set_xlabel('Производительность питающих насосов, 1/мин')
ax.set_ylabel('Число точек данных')

plt.show();

# %% [markdown]
# Перейдем к пункту 2. Заполним недостающие строки по ХА.

# %%
int_cols = [
    'Fe',
    'Stot',
    'SO4',
    'As',
    'Corg',
    'Ctot',
    'D_S',
    'D_SL_H'
]

df_work[int_cols] = df_work.loc[:, int_cols].interpolate(method='time')

# %% [markdown]
# Сохраним полученный файл

# %%
comp = {
        'method': 'zip',
        'archive_name': 'out.csv'
    }

filepath = Path(f'./{WORK_DIR}/df_work_ds.zip')

df_work.to_csv(filepath, compression=comp)

# %% [markdown]
# Если мы не изменяем исходники, то просто загружаем файлик

# %%
df_work = pd.read_csv(f'{WORK_DIR}\df_work_ds.zip', index_col=0, parse_dates=True)

# %% [markdown]
# ## Чистка данных для моделирования

# %% [markdown]
# Нужно добавить следующие данные:
# - Содержание твердого - C_S
# - Расход пульпы - Q_SL
# - Расход твердого - G_S
# - Расход серного эквивалента - G_Seq
#
# Константы:
# - Максимальная производительность насоса Feluwa 17,45 м³/ч
# - Максимальное число шагов 51
# - Мышьяк в СЭ - 0,371

# %%
FELUWA_MAX_Q = 17.45
FELUWA_MAX_N = 51
COEF_AS_SEQ = 0.371
D_WATER = 1000

# %%
fel_sum = df_work['Fel_1'] + df_work['Fel_2']

df_work = df_work.assign(Fel_sum = fel_sum.values)

# %%
df_work = df_work.assign(C_S = (df_work['D_S'] * D_WATER - df_work['D_SL_H'] * df_work['D_S']) / (df_work['D_SL_H'] * D_WATER - df_work['D_SL_H'] * df_work['D_S']) * 100)
df_work = df_work.assign(Q_SL = df_work['Fel_sum'] / FELUWA_MAX_N * FELUWA_MAX_Q)
df_work = df_work.assign(G_S = df_work['Q_SL'] * df_work['D_SL_H'] / 1000 * (df_work['C_S'] / 100))
df_work = df_work.assign(G_Seq = (COEF_AS_SEQ * df_work['As'] / 100 + df_work['Stot'] / 100) * df_work['G_S'])

# %% [markdown]
# В колонке SO4 много пропусков и нет доверия к анализу, уберем пока ее вообще.

# %%
df_work.drop('SO4', axis=1, inplace=True)

# %%
df_work.dropna(axis=0, inplace=True)

# %%
df_work.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 11486 entries, 2019-01-02 00:00:00 to 2021-12-01 17:00:00
# Data columns (total 56 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Fel_1          11486 non-null  float64
#  1   Fel_2          11486 non-null  float64
#  2   D_SL           11486 non-null  float64
#  3   QQ_C1          11486 non-null  float64
#  4   QQ_C2          11486 non-null  float64
#  5   QQ_C3          11486 non-null  float64
#  6   QQ_C4          11486 non-null  float64
#  7   QQ_C5          11486 non-null  float64
#  8   O2_tot         11486 non-null  float64
#  9   QQ_tot         11486 non-null  float64
#  10  Sl_tot         11486 non-null  float64
#  11  O2_C1          11486 non-null  float64
#  12  O2_C2          11486 non-null  float64
#  13  O2_C3          11486 non-null  float64
#  14  O2_C4          11486 non-null  float64
#  15  O2_C5          11486 non-null  float64
#  16  AC_level       11486 non-null  float64
#  17  AC_rbk_open    11486 non-null  float64
#  18  AC_valve_open  11486 non-null  float64
#  19  P_H2O          11486 non-null  float64
#  20  P_O2           11486 non-null  float64
#  21  P_tot          11486 non-null  float64
#  22  P_valve        11486 non-null  float64
#  23  P_tot_2        11486 non-null  float64
#  24  T_C1           11486 non-null  float64
#  25  T_C2           11486 non-null  float64
#  26  T_C3           11486 non-null  float64
#  27  T_C4           11486 non-null  float64
#  28  T_C5           11486 non-null  float64
#  29  T_abg          11486 non-null  float64
#  30  P_O2_in        11486 non-null  float64
#  31  FT1_level      11486 non-null  float64
#  32  FT1_P          11486 non-null  float64
#  33  FT1_T_in       11486 non-null  float64
#  34  FT1_T          11486 non-null  float64
#  35  FT2_level      11486 non-null  float64
#  36  FT2_P          11486 non-null  float64
#  37  FT2_T          11486 non-null  float64
#  38  Cond_Q         11486 non-null  float64
#  39  Cond_level     11486 non-null  float64
#  40  Cond_valve     11486 non-null  float64
#  41  O2_conc_1      11486 non-null  float64
#  42  O2_conc_2      11486 non-null  float64
#  43  Fe             11486 non-null  float64
#  44  Stot           11486 non-null  float64
#  45  As             11486 non-null  float64
#  46  Corg           11486 non-null  float64
#  47  Ctot           11486 non-null  float64
#  48  Fe2+           11486 non-null  float64
#  49  D_S            11486 non-null  float64
#  50  D_SL_H         11486 non-null  float64
#  51  Fel_sum        11486 non-null  float64
#  52  C_S            11486 non-null  float64
#  53  Q_SL           11486 non-null  float64
#  54  G_S            11486 non-null  float64
#  55  G_Seq          11486 non-null  float64
# dtypes: float64(56)
# memory usage: 5.0 MB

# %%
df_work.describe().T

# %% [markdown]
# ## Проведем анализ статистик признаков

# %% [markdown]
# ### Целевой признак - $Fe^{2+}$

# %%
df_work['Fe2+'].describe()
# Out:
# count   11,486.00
# mean         1.41
# std          1.01
# min          0.00
# 25%          1.02
# 50%          1.30
# 75%          1.69
# max         74.40
# Name: Fe2+, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(8, 10))

sns.boxplot(data=df_work, y='Fe2+', x=df_work.index.year);

ax.set_xlabel('Год')
ax.set_ylabel('Концентрация $Fe^{2+}$, г/л')

plt.show();

# %% [markdown]
# По всей видимости, точка со значением 74,4 одна и является выбросом. Найдем ее и посмотрим.

# %%
df_work[df_work['Fe2+']==74.4]
# Out:
#                      Fel_1  Fel_2     D_SL  QQ_C1  QQ_C2  QQ_C3  QQ_C4  QQ_C5  \
# 2020-03-09 20:00:00   0.00  47.43 1,681.45   6.44  25.67  15.97   7.93   3.02
#
#                       O2_tot  QQ_tot  ...  Corg  Ctot  Fe2+      D_S   D_SL_H  \
# 2020-03-09 20:00:00 4,766.73   59.03  ...  0.40  1.49 74.40 3,600.00 1,605.83
#
#                      Fel_sum   C_S  Q_SL   G_S  G_Seq
# 2020-03-09 20:00:00    47.43 52.24 16.23 13.61   3.40
#
# [1 rows x 56 columns]

# %%
df_work.loc['2020-03-09 20:00':'2020-03-10 2:00']
# Out:
#                      Fel_1  Fel_2     D_SL  QQ_C1  QQ_C2  QQ_C3  QQ_C4  QQ_C5  \
# 2020-03-09 20:00:00   0.00  47.43 1,681.45   6.44  25.67  15.97   7.93   3.02
# 2020-03-09 21:00:00   0.00  46.46 1,674.78   6.35  25.84  16.17   8.10   3.01
# 2020-03-09 22:00:00   0.00  43.38 1,663.58   6.35  26.28  16.28   7.84   3.04
# 2020-03-09 23:00:00   0.00  40.88 1,651.11   6.22  25.55  15.51   4.84   2.99
# 2020-03-10 00:00:00   0.00  39.49 1,640.92   5.84  25.68  14.88   3.35   2.95
# 2020-03-10 01:00:00   0.00  39.42 1,639.09   5.63  25.32  14.02   2.31   2.89
# 2020-03-10 02:00:00   0.00  41.24 1,636.65   5.33  25.30  14.35   3.13   2.92
#
#                       O2_tot  QQ_tot  ...  Corg  Ctot  Fe2+      D_S   D_SL_H  \
# 2020-03-09 20:00:00 4,766.73   59.03  ...  0.40  1.49 74.40 3,600.00 1,605.83
# 2020-03-09 21:00:00 4,786.39   59.46  ...  0.41  1.49 14.08 3,600.00 1,606.67
# 2020-03-09 22:00:00 4,788.25   59.79  ...  0.41  1.49  5.61 3,600.00 1,607.50
# 2020-03-09 23:00:00 4,792.34   55.12  ...  0.42  1.48  1.51 3,600.00 1,608.33
# 2020-03-10 00:00:00 4,789.98   52.71  ...  0.42  1.48  0.57 3,600.00 1,609.17
# 2020-03-10 01:00:00 4,791.27   50.18  ...  0.43  1.48  0.47 3,600.00 1,610.00
# 2020-03-10 02:00:00 4,789.64   51.03  ...  0.43  1.48  0.65 3,600.00 1,610.83
#
#                      Fel_sum   C_S  Q_SL   G_S  G_Seq
# 2020-03-09 20:00:00    47.43 52.24 16.23 13.61   3.40
# 2020-03-09 21:00:00    46.46 52.28 15.90 13.35   3.34
# 2020-03-09 22:00:00    43.38 52.33 14.84 12.49   3.13
# 2020-03-09 23:00:00    40.88 52.37 13.99 11.78   2.95
# 2020-03-10 00:00:00    39.49 52.42 13.51 11.40   2.86
# 2020-03-10 01:00:00    39.42 52.46 13.49 11.39   2.86
# 2020-03-10 02:00:00    41.24 52.51 14.11 11.93   3.00
#
# [7 rows x 56 columns]

# %% [markdown]
# Значения за 22 и 23 часа выпадают, уберем их в ручную, а затем интерполируем по соседним значениям. **Нужна функция чистки значений.**

# %%
df_work.loc['2020-03-09 20:00:00', 'Fe2+'] = np.NaN
df_work.loc['2020-03-09 21:00:00', 'Fe2+'] = np.NaN

# %%
df_work['Fe2+'].interpolate(method='time', inplace=True)

# %% [markdown]
# Посмотрим еще раз на распределение значений целевой переменной, после очистки.

# %%
fig, ax = plt.subplots(figsize=(10, 10))

sns.boxplot(data=df_work, y='Fe2+', x=df_work.index.year, ax=ax);
ax.set_ylim(0, 12.5)
# Out:
# (0.0, 12.5)

# %%
src.plot_moving_average(df_work.loc[:, ['Fe2+']], window=2, plot_intervals=True, plot_anomalies=True, scale=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 src.plot_moving_average(df_work.loc[:, ['Fe2+']], window=2, plot_intervals=True, plot_anomalies=True, scale=3)
#
# NameError: name 'df_work' is not defined

# %%
f, ax = plt.subplots(figsize=(15,5))

ax.plot(df_work['Fe2+'].values, label="Концентрация $Fe^{2+}$, г/л")

rolling_mean = df_work['Fe2+'].rolling(window=12).mean()
ax.plot(rolling_mean.values, c='red', label="Скользящее среднее")

f.tight_layout();

ax.set_ylabel('Концентрация $Fe^{2+}$, г/л')
ax.set_xlabel('Точки данных')

plt.legend()
plt.show();

# %%
df_work.loc[df_work['Fe2+'] > 10, :]
# Out:
#                      Fel_1  Fel_2     D_SL  QQ_C1  QQ_C2  QQ_C3  QQ_C4  QQ_C5  \
# 2019-02-01 08:00:00  24.37   0.00 1,605.35   4.87  13.91   2.46   5.62  -0.00
# 2019-02-01 09:00:00  31.27   0.00 1,599.31   6.07  23.29   2.01  10.32  -0.00
# 2020-04-20 21:00:00  21.83   0.00 1,664.27   5.64   7.96   4.09   1.71   1.07
# 2020-04-23 06:00:00  18.78  29.36 1,635.54  17.55  34.21  16.90   3.08   1.58
# 2020-05-27 05:00:00  22.77   4.80 1,607.73  11.76  20.59   8.25   4.31   2.82
# 2021-01-16 19:00:00  43.78   0.00 1,001.45  22.37  23.94  16.28   7.60   2.25
# 2021-04-02 20:00:00   0.00  49.00 1,750.24  25.17  31.81  19.43   7.07   1.70
# 2021-08-04 17:00:00  25.89  25.96 1,001.94  18.91  24.49  15.10   5.70   1.68
# 2021-08-21 20:00:00  24.96  19.51 1,759.71  20.51  27.39  14.74   5.42   1.61
#
#                       O2_tot  QQ_tot  ...  Corg  Ctot  Fe2+      D_S   D_SL_H  \
# 2019-02-01 08:00:00 2,950.43   26.85  ...  0.34  1.00 11.46 3,900.00 1,567.21
# 2019-02-01 09:00:00 4,250.47   41.70  ...  0.34  0.99 11.46 3,900.00 1,566.92
# 2020-04-20 21:00:00 1,850.08   20.46  ...  0.53  1.00 12.12 4,000.00 1,619.18
# 2020-04-23 06:00:00 5,074.79   73.32  ...  0.54  0.98 10.70 4,000.00 1,598.25
# 2020-05-27 05:00:00 3,189.42   47.75  ...  0.56  0.92 11.65 4,000.00 1,681.83
# 2021-01-16 19:00:00 5,124.79   72.43  ...  0.61  1.03 10.70 4,000.00 1,704.00
# 2021-04-02 20:00:00 7,128.75   85.18  ...  0.49  0.95 10.40 3,900.00 1,757.50
# 2021-08-04 17:00:00 4,471.57   65.86  ...  0.32  0.60 12.30 3,800.00 1,571.17
# 2021-08-21 20:00:00 5,120.06   69.65  ...  0.72  1.16 20.28 3,700.00 1,741.67
#
#                      Fel_sum   C_S  Q_SL   G_S  G_Seq
# 2019-02-01 08:00:00    24.37 48.67  8.34  6.36   2.01
# 2019-02-01 09:00:00    31.27 48.66 10.70  8.16   2.58
# 2020-04-20 21:00:00    21.83 50.99  7.47  6.17   1.82
# 2020-04-23 06:00:00    48.14 49.91 16.47 13.14   3.88
# 2020-05-27 05:00:00    27.57 54.05  9.43  8.58   2.53
# 2021-01-16 19:00:00    43.78 55.09 14.98 14.06   4.21
# 2021-04-02 20:00:00    49.00 57.96 16.77 17.08   5.16
# 2021-08-04 17:00:00    51.85 49.34 17.74 13.75   3.68
# 2021-08-21 20:00:00    44.47 58.36 15.21 15.46   4.52
#
# [9 rows x 56 columns]

# %%
df_work.loc[df_work['Fe2+'] == 0, :]
# Out:
#                      Fel_1  Fel_2     D_SL  QQ_C1  QQ_C2  QQ_C3  QQ_C4  QQ_C5  \
# 2019-09-19 08:00:00  14.82  14.51 1,606.12  14.77  20.04   5.87   0.95   0.42
# 2019-09-19 09:00:00   0.00  24.78 1,606.66  12.48  15.78   3.29   1.65   0.50
# 2020-07-06 07:00:00  37.44   0.00 1,600.54  13.99  31.45  15.78   4.71   0.27
#
#                       O2_tot  QQ_tot  ...  Corg  Ctot  Fe2+      D_S   D_SL_H  \
# 2019-09-19 08:00:00 3,720.37   42.04  ...  0.38  0.82  0.00 3,900.00 1,601.53
# 2019-09-19 09:00:00 2,978.67   33.71  ...  0.38  0.82  0.00 3,900.00 1,603.89
# 2020-07-06 07:00:00 4,821.31   66.21  ...  0.36  0.72  0.00 3,890.00 1,638.00
#
#                      Fel_sum   C_S  Q_SL   G_S  G_Seq
# 2019-09-19 08:00:00    29.33 50.51 10.04  8.12   2.27
# 2019-09-19 09:00:00    24.78 50.63  8.48  6.88   1.93
# 2020-07-06 07:00:00    37.44 52.43 12.81 11.00   3.50
#
# [3 rows x 56 columns]

# %% [markdown]
# Оставшиеся выбросы не будем пока убирать, так как это могут быть технологические отклонения. Посмотрим как они будут описываться моделью.

# %%
less_one = df_work.loc[df_work['Fe2+'] <= 1, ['Fe2+']].count()
one_two = df_work.loc[(df_work['Fe2+'] > 1) & (df_work['Fe2+'] <= 2), ['Fe2+']].count()
more_two = df_work.loc[df_work['Fe2+'] > 2, ['Fe2+']].count()

print(less_one.values, one_two.values, more_two.values)
# Out:
# [2750] [7387] [1349]

# %%
f, ax = plt.subplots(figsize=(8, 5))

sns.histplot(df_work['Fe2+'], ax=ax)

f.tight_layout();

ax.set_xlabel('Концентрация $Fe^{2+}$, г/л')
ax.set_ylabel('Число точек')

ax.set_ylim(0, 700)
ax.set_xlim(0, 20)

plt.show();

# %% [markdown]
# ## Анализ состава исходного сырья

# %% [markdown]
# Выделим нужные колонки и посмотрим на распределения данных.
#
# В химическом анализе из баков питания могут быть выбросы или неправильные значения. В какие-то дни анализы могут быть неполными. Проверим по $Fe$ и $S_{tot}$.

# %%
df_work.loc[(df_work['Fe'] <= 10) & (df_work['Stot'] <= 10), ['Fe', 'Stot']].count()
# Out:
# Fe      0
# Stot    0
# dtype: int64

# %%
int_cols = [
    'Fe',
    'Stot',
    'As',
    'Corg',
    'Ctot'
]

df_work[int_cols].describe()
# Out:
#              Fe      Stot        As      Corg      Ctot
# count 11,486.00 11,486.00 11,486.00 11,486.00 11,486.00
# mean      27.36     26.47      7.75      0.64      1.04
# std        3.64      2.16      1.68      1.90      0.24
# min       16.41     19.10      1.50      0.12      0.35
# 25%       25.12     25.63      6.79      0.44      0.92
# 50%       27.57     26.71      7.70      0.52      1.01
# 75%       29.59     27.69      8.80      0.62      1.12
# max       47.19     33.70     13.93     71.00      2.15

# %% [markdown]
# Посмотрим на анализ органического углерода, судя по исходному распределению, там есть выбросы и/или ошибки. Проверим точки где органического углерода по анализу больше общего. Попробуем приравнять в таких точках значение органического углерода к общему.

# %%
df_work.loc[df_work['Corg'] > df_work['Ctot'], 'Corg'] = df_work.loc[df_work['Corg'] > df_work['Ctot'], 'Ctot']

# %%
df_work.loc[df_work['Corg'] > df_work['Ctot']].count().sum()
# Out:
# 0

# %%
df_work[int_cols].describe()
# Out:
#              Fe      Stot        As      Corg      Ctot
# count 11,486.00 11,486.00 11,486.00 11,486.00 11,486.00
# mean      27.36     26.47      7.75      0.56      1.04
# std        3.64      2.16      1.68      0.21      0.24
# min       16.41     19.10      1.50      0.12      0.35
# 25%       25.12     25.63      6.79      0.44      0.92
# 50%       27.57     26.71      7.70      0.52      1.01
# 75%       29.59     27.69      8.80      0.62      1.12
# max       47.19     33.70     13.93      1.84      2.15

# %%
f, ax = plt.subplots(5, 1, figsize=(15,30), sharex=True)

for i, col in enumerate(int_cols):
    ax[i].plot(df_work[col].values)
    # rolling_mean = df_work[col].rolling(window=12).mean()
    # ax[i].plot(rolling_mean.values, c='red', alpha=0.5)
    ax[i].set_ylabel(f'Содержание {col}, %')

f.tight_layout();

ax[4].set_xlabel('Точки данных')

plt.show();

# %%
f, ax = plt.subplots(1, 5, figsize=(20,5))

for i, col in enumerate(int_cols):
    sns.boxplot(data=df_work, y=col, ax=ax[i])
    ax[i].set_ylabel(f'Содержание {col}, %')

f.tight_layout();

plt.show();

# %% [markdown]
# ## Анализ данных работы автоклава

# %% [markdown]
# ### Насосы питания

# %%
df[['Fel_1', 'Fel_2']].describe().T
# Out:
#           count  mean   std  min  25%  50%   75%   max
# Fel_1 23,898.00 14.16 18.85 0.00 0.00 0.00 34.20 50.51
# Fel_2 23,898.00  8.27 15.42 0.00 0.00 0.00  0.00 49.94

# %%
f, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=df_work, y='Fel_1', ax=axs[0], x=df_work.index.year);
sns.boxplot(data=df_work, y='Fel_2', ax=axs[1], x=df_work.index.year);

# %% [markdown]
# Достаточно часто используемый в стаистике график, описывающий распределение параметра. Предполагается что распределение параметра носит нормальных характер. Описание графика boxplot:
#
# <img src=".\working_data\Boxplot_vs_PDF.svg.png" width=30%>
#
# *источник картинки wikipedia*

# %%
f, ax = plt.subplots(figsize=(15,5))

plt.plot(df_work['Fel_1'].resample('H').first().fillna(value=np.nan))
plt.plot(df_work['Fel_2'].resample('H').first().fillna(value=np.nan))

ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%y'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
ax.set_ylim([0, 60])
ax.legend(['Насос 101', 'Насос 103'])

f.autofmt_xdate();
f.tight_layout();

ax.set_title('Производительность насосов по шагам')
ax.set_ylabel('Шаги поршня, 1/мин')

plt.show()

# %%
f, ax = plt.subplots(figsize=(15,5))

fel_sum = df_work['Fel_1'] + df_work['Fel_2']

plt.plot(fel_sum.resample('H').first().fillna(value=np.nan))

ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%y'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
ax.set_ylim([0, 90])

f.autofmt_xdate();
f.tight_layout();

ax.set_title('Производительность насосов по шагам суммарно')
ax.set_ylabel('Шаги поршня, 1/мин')

plt.show();

# %%
f, ax = plt.subplots(2, 1, figsize=(15,10), sharex=True)

ax[0].plot(df_work['Fel_1'].values)
ax[1].plot(df_work['Fel_2'].values)

# rolling_mean = df_work['D_SL'].rolling(window=48).mean()
# ax.plot(rolling_mean.values, c='red')

f.tight_layout();

st = f.suptitle('Производительность насосов 1 и 2')
st.set_y(0.95)
f.subplots_adjust(top=0.9)

ax[0].set_ylabel('Шаги поршня, 1/мин')
ax[1].set_ylabel('Шаги поршня, 1/мин')

plt.show();

# %%
f, ax = plt.subplots(figsize=(15,5))

plt.plot(fel_sum.values)

ax.set_ylim([0, 90])

f.tight_layout();

# ax.set_title('Производительность насосов по шагам суммарно')
ax.set_ylabel('Шаги поршня, 1/мин')
ax.set_xlabel('Точки данных')

plt.show();

# %% [markdown]
# ### Плотность пульпы

# %%
f, ax = plt.subplots(figsize=(15,5))

ax.scatter(df_work.index, df_work['D_SL'])

ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%y'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
# ax.set_ylim([0, 90])

# rolling_mean = df_work['D_SL'].rolling(window=36).mean()
# ax.plot(df_work.index, rolling_mean, c='red')

f.autofmt_xdate();
f.tight_layout();

ax.set_title('Плотность пульпы питания по плотномеру бака питания автоклава АС101')
ax.set_ylabel('Плотность, кг/м³')

plt.show();

# %%
f, ax = plt.subplots(figsize=(15,5))

ax.plot(df_work['D_SL'].values)

# rolling_mean = df_work['D_SL'].rolling(window=48).mean()
# ax.plot(rolling_mean.values, c='red')

f.tight_layout();

ax.set_title('Плотность пульпы питания по плотномеру бака питания автоклава АС101')
ax.set_ylabel('Плотность, кг/м³')

plt.show();

# %%
src.plot_moving_average(df_work.loc[:, ['D_SL']], window=36, plot_intervals=True, plot_anomalies=True)

# %% [markdown]
# Разброс параметра большой. Скорее всего нужно будет корректировать по результатам ручных замеров.

# %%
f, ax = plt.subplots(figsize=(15,5))

ax.plot(df_work['D_SL'].values, label="Плотномер (АСУТП)")
ax.plot(df_work['D_SL_H'].values, label="Ручной замер (ОТК)")

# rolling_mean = df_work['D_SL'].rolling(window=48).mean()
# ax.plot(rolling_mean.values, c='red')

f.tight_layout();

# ax.set_title('Плотность пульпы питания по плотномеру бака питания автоклава АС101')
ax.set_ylabel('Плотность пульпы бака питания AC101, кг/м³')
ax.set_xlabel('Точки данных')
ax.set_xlim(-500, 12000)

plt.legend()

plt.show();

# %%
f, axs = plt.subplots(1, 2, figsize=(8, 5), sharey=True)

sns.boxplot(data=df_work, y='D_SL', ax=axs[0])
axs[0].set_ylabel('Плотность пульпы, кг/м³')
axs[0].set_xlabel('Данные АСУТП')

sns.boxplot(data=df_work, y='D_SL_H', ax=axs[1])
axs[1].set_ylabel('')
axs[1].set_xlabel('Данные ручных замеров')

f.tight_layout()

plt.show()

# %%
f, ax = plt.subplots(figsize=(15,5))

ax.plot(df_work['D_S'].values)

f.tight_layout()

# ax.set_title('Плотность твердого в баке питания автоклава АС101')
ax.set_ylabel('Плотность, кг/м³')
ax.set_xlabel('Точки данных')
ax.set_xlim(-500, 12000)

plt.show();

# %% [markdown]
# ### Расход воды по секциям и общий расход

# %%
QQ_cols = [
    'QQ_C1',
    'QQ_C2',
    'QQ_C3',
    'QQ_C4',
    'QQ_C5',
    'QQ_tot',
]

# %%
df_work[QQ_cols].describe().T
# Out:
#            count  mean   std  min   25%   50%   75%   max
# QQ_C1  11,486.00 18.39  6.90 0.00 14.14 19.82 22.87 31.43
# QQ_C2  11,486.00 30.16  6.13 0.10 26.11 30.37 34.52 44.38
# QQ_C3  11,486.00 16.30  3.69 0.00 15.57 17.29 18.38 21.73
# QQ_C4  11,486.00  5.52  2.11 0.01  4.20  5.49  7.07 11.89
# QQ_C5  11,486.00  2.13  1.61 0.00  0.90  1.97  2.87  7.64
# QQ_tot 11,486.00 72.50 13.85 0.79 68.10 73.88 82.35 97.32

# %%
f, ax = plt.subplots(5, 1, figsize=(15,25), sharex=True)

for i, col in enumerate(QQ_cols[:-1]):
    ax[i].plot(df_work[col].values)
    rolling_mean = df_work[col].rolling(window=12).mean()
    ax[i].plot(rolling_mean.values, c='red')
    ax[i].set_title(f'Подача воды в секцию {col[-2:]}')
    ax[i].set_ylabel('Расход воды, нм³/ч')

ax[4].set_xlim(-500, 12000)

f.tight_layout();

plt.show();

# %%
f, ax = plt.subplots(1, 5, figsize=(20, 5), sharey=True)

for i, col in enumerate(QQ_cols[:-1]):
    sns.boxplot(data=df_work, y=col, ax=ax[i])
    ax[i].set_ylabel('')
    ax[0].set_ylabel('Расход воды, нм³/ч')
    ax[i].set_xlabel(col[-2:])

f.tight_layout();

plt.show();

# %% [markdown]
# ### Температура

# %%
T_cols = [
    'T_C1',
    'T_C2',
    'T_C3',
    'T_C4',
    'T_C5',
    'T_abg'
]

# %%
df_work[T_cols].describe().T
# Out:
#           count   mean   std    min    25%    50%    75%    max
# T_C1  11,486.00 218.38 17.08 130.30 219.98 224.87 225.02 233.23
# T_C2  11,486.00 220.38  8.87 136.06 219.99 224.84 225.02 232.48
# T_C3  11,486.00 208.61 15.28 132.99 198.05 209.37 224.91 232.26
# T_C4  11,486.00 220.56  9.69 125.67 217.86 224.48 225.43 234.02
# T_C5  11,486.00 207.65 17.74 126.38 190.69 215.18 221.29 230.72
# T_abg 11,486.00 223.51  2.66 187.01 222.85 224.02 225.06 230.02

# %%
f, ax = plt.subplots(figsize=(15,5))

for col in T_cols:
    ax.plot(df_work[col].values)

f.tight_layout();

ax.set_title('Температура по секциям автоклава АС101')
ax.set_ylabel('Температура, °С')
ax.set_xlim(-500, 12000)

ax.legend(T_cols)

plt.show();

# %%
f, ax = plt.subplots(figsize=(15,5))

# ax.scatter(df_work.index, df_work['QQ_C1'])
for col in T_cols[:-1]:
    ax.plot(df_work[col].resample('H').first().fillna(value=np.nan))

    ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%y'))
    ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
    # ax.set_ylim([0, 90])

# rolling_mean = df_work['D_SL'].rolling(window=36).mean()
# ax.plot(df_work.index, rolling_mean, c='red')

f.autofmt_xdate();
f.tight_layout();

ax.set_title('Температура по секциям автоклава АС101')
ax.set_ylabel('Температура, °С')

ax.legend(T_cols[:-1])

plt.show();

# %% [markdown]
# Посмотрим где температура не отличается от 225 °С более чем на 10 градусов.

# %%
for col in T_cols[:-1]:
    delta = 5
    print(f'Для секции {col} значений с разницей меньше {delta} °С: {df_work.loc[(-df_work[col] + 225) <=delta, [col]].count()[0]}')
# Out:
# Для секции T_C1 значений с разницей меньше 5 °С: 8468
# Для секции T_C2 значений с разницей меньше 5 °С: 8347
# Для секции T_C3 значений с разницей меньше 5 °С: 3757
# Для секции T_C4 значений с разницей меньше 5 °С: 7778
# Для секции T_C5 значений с разницей меньше 5 °С: 3525

# %% [markdown]
# Получается что хуже всего температура измеряется в секциях 3 и 5. Там меньше половины точек больше 220 °С.

# %% [markdown]
# #### Взаимосвязь воды и температуры

# %% [markdown]
# Выберем те данные в которых температура по секциям была выше 220 °С. По всем секциям.

# %%
df_corr_T_QQ = df_work.loc[
    (df_work["T_C1"] >= 220)
    & (df_work["T_C2"] >= 220)
    & (df_work["T_C3"] >= 220)
    & (df_work["T_C4"] >= 220)
    & (df_work["T_C5"] >= 220),
    T_cols + QQ_cols[:-1],
]

# %%
df_corr_T_QQ.describe().T
# Out:
#          count   mean  std    min    25%    50%    75%    max
# T_C1  2,226.00 226.43 2.09 220.23 224.99 225.14 228.17 233.23
# T_C2  2,226.00 225.72 1.85 220.05 224.99 225.04 226.74 232.48
# T_C3  2,226.00 226.20 1.57 220.09 225.01 226.03 227.26 232.26
# T_C4  2,226.00 226.25 2.06 220.04 224.86 225.53 227.97 234.02
# T_C5  2,226.00 223.76 1.78 220.02 222.39 223.91 225.09 230.72
# T_abg 2,226.00 224.39 1.57 216.34 223.24 224.33 225.55 230.02
# QQ_C1 2,226.00  20.77 7.98   0.10  17.10  23.98  26.19  31.33
# QQ_C2 2,226.00  31.30 4.33  12.61  29.67  31.62  34.09  38.72
# QQ_C3 2,226.00  17.64 1.85   3.29  16.74  17.59  19.01  20.34
# QQ_C4 2,226.00   6.35 2.16   0.01   4.70   6.81   8.11  10.10
# QQ_C5 2,226.00   1.69 1.44   0.00   0.66   1.12   2.52   6.48

# %%
corr = df_corr_T_QQ.corr()

mask = np.triu(np.ones_like(corr))

plt.figure(figsize=(10, 10))
sns.heatmap(corr, annot=True, cmap='Spectral', mask=mask);
plt.yticks(rotation=0)
plt.show()

# %%
f, ax = plt.subplots(figsize=(15,5))

for col in T_cols:
    ax.plot(df_corr_T_QQ[col].values)

# rolling_mean = df_work['D_SL'].rolling(window=36).mean()
# ax.plot(df_work.index, rolling_mean, c='red')

f.tight_layout();

ax.set_title('Температура по секциям автоклава АС101')
ax.set_ylabel('Температура, °С')

ax.legend(T_cols)

plt.show();

# %% [markdown]
# Посмотрим распределение температур по секциям, для отобранных данных.

# %%
cdf = pd.concat(
    [
        df_corr_T_QQ[["T_C1"]].assign(S=1),
        df_corr_T_QQ[["T_C2"]].assign(S=2),
        df_corr_T_QQ[["T_C3"]].assign(S=3),
        df_corr_T_QQ[["T_C4"]].assign(S=4),
        df_corr_T_QQ[["T_C5"]].assign(S=5),
    ]
)

mdf = pd.melt(cdf, id_vars="S")

f, ax = plt.subplots(figsize=(15, 5))

ax = sns.boxplot(data=mdf, y="value", x="S")
ax.set_ylabel("Температура, °С")
ax.set_xlabel("Номер секции")
ax.set_ylim([215, 235])

plt.show()

# %% [markdown]
# А теперь посмотрим во времени, когда температурные датчики автоклава показывали корректные значения.

# %%
f, ax = plt.subplots(figsize=(15,5))

# ax.scatter(df_work.index, df_work['QQ_C1'])
for col in T_cols[:-1]:
    ax.plot(df_corr_T_QQ[col].resample('H').first().fillna(value=np.nan))

    ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%y'))
    ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
    # ax.set_ylim([0, 90])

# rolling_mean = df_work['D_SL'].rolling(window=36).mean()
# ax.plot(df_work.index, rolling_mean, c='red')

f.autofmt_xdate();
f.tight_layout();

ax.set_title('Температура по секциям автоклава АС101')
ax.set_ylabel('Температура, °С')

ax.legend(T_cols[:-1])

plt.show();

# %% [markdown]
# ### Давление в автоклаве и расход кислорода

# %%
O2_cols = [
    'O2_C1',
    'O2_C2',
    'O2_C3',
    'O2_C4',
    'O2_C5',
    'O2_conc_1',
    'O2_conc_2',
]

P_cols = [
    'P_H2O',
    'P_O2',
    'P_tot',
    'P_valve'
]

# %% [markdown]
# Посмотрим общие статистики по подаче кислорода.

# %%
df_work[O2_cols].describe().T
# Out:
#               count     mean    std  min      25%      50%      75%      max
# O2_C1     11,486.00 2,160.50 325.30 0.00 1,939.64 2,157.41 2,398.44 3,046.64
# O2_C2     11,486.00 1,960.88 283.03 0.00 1,777.06 1,927.66 2,180.01 2,705.14
# O2_C3     11,486.00   999.57 188.27 0.00   892.01   971.74 1,112.96 1,598.46
# O2_C4     11,486.00   380.75 107.73 0.00   342.29   381.90   429.93   850.34
# O2_C5     11,486.00   153.04  45.09 0.00   120.01   157.46   178.98   300.19
# O2_conc_1 11,486.00    69.56  44.66 0.00     0.00    95.00    99.90   100.00
# O2_conc_2 11,486.00    92.70  25.08 0.00    99.40    99.50    99.60   100.00

# %%
f, ax = plt.subplots(5, 1, figsize=(15,25), sharex=True)

for i, col in enumerate(O2_cols[:-2]):
    ax[i].plot(df_work[col].values)
    # rolling_mean = df_work[col].rolling(window=24).mean()
    # ax[i].plot(rolling_mean.values, c='red')
    ax[i].set_title(f'Подача кислорода в секцию {col[-2:]}')
    ax[i].set_ylabel('Расход кислорода, нм³/ч')

ax[4].set_xlim(-500, 12000)
f.tight_layout();

plt.show();

# %%
f, ax = plt.subplots(1, 5, figsize=(20, 5), sharey=True)

for i, col in enumerate(O2_cols[:-2]):
    sns.boxplot(data=df_work, y=col, ax=ax[i])
    ax[i].set_ylabel('')
    ax[0].set_ylabel('Расход кислорода, нм³/ч')
    ax[i].set_xlabel(col[-2:])

f.tight_layout();

plt.show();

# %% [markdown]
# Данные по чистоте кислорода использовать, скорее всего, нецелесообразно ввиду их практически постоянства.

# %%
f, ax = plt.subplots(figsize=(15,5))

plt.plot(df_work['O2_conc_1'].values)
plt.plot(df_work['O2_conc_2'].values)

ax.set_ylabel('Концентрация кислорода, %')

plt.show();

# %% [markdown]
# Давление P_tot и P_tot_2 целесообразно объединить в одно значение, взяв среднее.

# %%
df_work = df_work.assign(P_tot = df_work[['P_tot', 'P_tot_2']].mean(axis=1))

# %%
df_work.drop('P_tot_2', inplace=True, axis=1)

# %% [markdown]
# Посмотрим общие статистики по давлению

# %%
df_work[P_cols].describe().T
# Out:
#             count  mean   std   min   25%   50%   75%    max
# P_H2O   11,486.00 24.62  1.10 17.36 24.29 24.77 25.28  27.47
# P_O2    11,486.00  6.08  0.66  2.93  5.65  6.09  6.55   8.40
# P_tot   11,486.00 29.71  0.91 20.79 29.98 29.99 30.01  31.28
# P_valve 11,486.00 46.10 21.69  0.00 27.93 43.82 62.52 100.00

# %% [markdown]
# Скорее всего общее давление можно вообще удалить, так как это точно линейная комбинация давления паров воды и парциального давления кислорода.

# %%
f, ax = plt.subplots(figsize=(15,5))

for col in ['P_H2O', 'P_O2']:
    ax.plot(df_work[col].values)
    # rolling_mean = df_work[col].rolling(window=24).mean()
    # ax.plot(rolling_mean.values, c='red')

f.tight_layout();

# ax.set_title('Давление кислорода и паров воды в АС101')
ax.set_ylabel('Давление, бар')
ax.set_xlabel('Точки данных')
ax.set_xlim(-500, 12000)

ax.legend(['Давление паров воды', 'Давление кислорода'])

plt.show();

# %% [markdown]
# Посмотрим распределение давления кислорода и паров воды.

# %%
f, axs = plt.subplots(1, 2, figsize=(10, 5))

sns.boxplot(data=df_work, y="P_H2O", ax=axs[0], width=0.5)
sns.boxplot(data=df_work, y="P_O2", ax=axs[1], width=0.5)

axs[0].set_ylabel('Давление паров воды, бар')
axs[1].set_ylabel('Давление кислорода, бар')
# Out:
# Text(0, 0.5, 'Давление кислорода, бар')

# %%
f, ax = plt.subplots(figsize=(15,5))

ax.plot(df_work['P_valve'].values)

# rolling_mean = df_work['P_valve'].rolling(window=24).mean()
# ax.plot(rolling_mean.values, c='red')

f.tight_layout();

# ax.set_title('Степень открытия клапана сброса давления в АС101')
ax.set_ylabel('Степень открытия, %')
ax.set_xlabel('Точки данных')
ax.set_xlim(-500, 12000)

plt.show();

# %% [markdown]
# А теперь посмотрим корреляции ) и для начала выберем нужные колонки с данными

# %%
corr_cols = [
    'O2_C1',
    'O2_C2',
    'O2_C3',
    'O2_C4',
    'O2_C5',
    'P_H2O',
    'P_O2',
    'P_valve',
    'QQ_C1',
    'QQ_C2',
    'QQ_C3',
    'QQ_C4',
    'QQ_C5',
    'Fe',
    'Stot',
    'As',
    'Corg',
    'Ctot',
    'Fe2+'
]

# %%
corr = df_work[corr_cols].corr()

mask = np.triu(np.ones_like(corr))

plt.figure(figsize=(15, 15))
sns.heatmap(corr, annot=True, cmap="Spectral", mask=mask);
plt.yticks(rotation=0)
plt.show();

# %% [markdown]
# Видно, что в исходных данных корреляций между параметрами практически нет.

# %% [markdown]
# ### Уровень в автоклаве и клапан сброса

# %%
l_cols = [
    'AC_level',
    # 'AC_rbk_open',
    'AC_valve_open'
]

# %%
df_work[l_cols].describe()
# Out:
#        AC_level  AC_valve_open
# count 11,486.00      11,486.00
# mean      65.31          21.56
# std        3.47          15.63
# min       52.68           0.01
# 25%       65.98           9.67
# 50%       66.00          17.00
# 75%       67.50          33.90
# max       85.85         100.00

# %%
f, ax = plt.subplots(figsize=(15,5))

for col in l_cols:
    ax.plot(df_work[col].values)

rolling_mean = df_work['AC_valve_open'].rolling(window=24).mean()
ax.plot(rolling_mean.values, c='green')

f.tight_layout();

ax.set_title('Уровень в АС / Степень открытия клапана')
ax.set_ylabel('Параметр, %')
ax.set_ylim([0, 100])
ax.set_xlim(-500, 12000)

ax.legend(l_cols + ['Скользящее среднее'])

plt.show();

# %% [markdown]
# ## Параметры СВД, СНД и конденсатора

# %% [markdown]
# На данный момент использование этих параметров нецелесообразно для моделирования работы автоклава.

# %% [markdown]
# # Сохраним итоговый файл для дальнейших расчётов

# %%
df_work[df_work < 0] = 0

# %%
df_work.describe().T
# Out:
#                   count     mean    std      min      25%      50%      75%  \
# Fel_1         11,486.00    29.33  17.11     0.00    25.00    35.50    43.00
# Fel_2         11,486.00    17.16  18.49     0.00     0.00     0.00    32.41
# D_SL          11,486.00 1,629.13 174.68   988.43 1,605.86 1,650.77 1,716.07
# QQ_C1         11,486.00    18.39   6.90     0.00    14.14    19.82    22.87
# QQ_C2         11,486.00    30.16   6.13     0.10    26.11    30.37    34.52
# QQ_C3         11,486.00    16.30   3.69     0.00    15.57    17.29    18.38
# QQ_C4         11,486.00     5.52   2.11     0.01     4.20     5.49     7.07
# QQ_C5         11,486.00     2.13   1.61     0.00     0.90     1.97     2.87
# O2_tot        11,486.00 5,654.75 835.75     0.00 5,199.94 5,455.04 6,266.38
# QQ_tot        11,486.00    72.50  13.85     0.79    68.10    73.88    82.35
# Sl_tot        11,486.00     2.34   5.85     0.00     0.00     0.00     0.00
# O2_C1         11,486.00 2,160.50 325.30     0.00 1,939.64 2,157.41 2,398.44
# O2_C2         11,486.00 1,960.88 283.03     0.00 1,777.06 1,927.66 2,180.01
# O2_C3         11,486.00   999.57 188.27     0.00   892.01   971.74 1,112.96
# O2_C4         11,486.00   380.75 107.73     0.00   342.29   381.90   429.93
# O2_C5         11,486.00   153.04  45.09     0.00   120.01   157.46   178.98
# AC_level      11,486.00    65.31   3.47    52.68    65.98    66.00    67.50
# AC_rbk_open   11,486.00    22.17  14.84     0.00    10.98    17.86    33.23
# AC_valve_open 11,486.00    21.56  15.63     0.01     9.67    17.00    33.90
# P_H2O         11,486.00    24.62   1.10    17.36    24.29    24.77    25.28
# P_O2          11,486.00     6.08   0.66     2.93     5.65     6.09     6.55
# P_tot         11,486.00    29.70   0.91    20.80    30.00    30.00    30.00
# P_valve       11,486.00    46.10  21.69     0.00    27.93    43.82    62.52
# P_tot_2       11,486.00    29.71   0.92    20.79    29.95    29.99    30.02
# T_C1          11,486.00   218.38  17.08   130.30   219.98   224.87   225.02
# T_C2          11,486.00   220.38   8.87   136.06   219.99   224.84   225.02
# T_C3          11,486.00   208.61  15.28   132.99   198.05   209.37   224.91
# T_C4          11,486.00   220.56   9.69   125.67   217.86   224.48   225.43
# T_C5          11,486.00   207.65  17.74   126.38   190.69   215.18   221.29
# T_abg         11,486.00   223.51   2.66   187.01   222.85   224.02   225.06
# P_O2_in       11,486.00    34.09   0.34    17.11    33.96    34.11    34.23
# FT1_level     11,486.00    45.93   9.26     0.00    43.29    47.03    50.65
# FT1_P         11,486.00     6.20   0.74     0.11     5.91     6.22     6.64
# FT1_T_in      11,486.00   186.63  19.18    92.16   171.42   183.84   202.95
# FT1_T         11,486.00   165.52   5.36    84.76   163.80   165.76   168.56
# FT2_level     11,486.00    43.41   8.01     0.00    39.98    40.02    45.02
# FT2_P         11,486.00     0.12   0.17     0.00     0.00     0.08     0.17
# FT2_T         11,486.00    99.47   9.43     8.53   101.24   101.77   102.15
# Cond_Q        11,486.00    16.97  19.68     0.00     0.00     0.02    38.06
# Cond_level    11,486.00    42.92  22.82     0.00    38.11    40.01    50.00
# Cond_valve    11,486.00     6.08   0.76     0.04     5.71     6.00     6.50
# O2_conc_1     11,486.00    69.56  44.66     0.00     0.00    95.00    99.90
# O2_conc_2     11,486.00    92.70  25.08     0.00    99.40    99.50    99.60
# Fe            11,486.00    27.36   3.64    16.41    25.12    27.57    29.59
# Stot          11,486.00    26.47   2.16    19.10    25.63    26.71    27.69
# As            11,486.00     7.75   1.68     1.50     6.79     7.70     8.80
# Corg          11,486.00     0.64   1.90     0.12     0.44     0.52     0.62
# Ctot          11,486.00     1.04   0.24     0.35     0.92     1.01     1.12
# Fe2+          11,486.00     1.40   0.73     0.00     1.02     1.30     1.69
# D_S           11,486.00 3,860.33 139.34 3,500.00 3,800.00 3,900.00 4,000.00
# D_SL_H        11,486.00 1,660.80  64.73 1,382.00 1,615.00 1,665.50 1,709.00
# Fel_sum       11,486.00    46.50   8.61    20.09    41.00    44.04    50.00
# C_S           11,486.00    53.60   3.23    37.37    51.65    53.83    55.92
# Q_SL          11,486.00    15.91   2.94     6.87    14.03    15.07    17.11
# G_S           11,486.00    14.16   2.67     5.40    12.74    13.98    15.54
# G_Seq         11,486.00     4.15   0.85     1.47     3.74     4.12     4.59
#
#                    max
# Fel_1            50.51
# Fel_2            49.94
# D_SL          2,035.59
# QQ_C1            31.43
# QQ_C2            44.38
# QQ_C3            21.73
# QQ_C4            11.89
# QQ_C5             7.64
# O2_tot        7,551.90
# QQ_tot           97.32
# Sl_tot           24.59
# O2_C1         3,046.64
# O2_C2         2,705.14
# O2_C3         1,598.46
# O2_C4           850.34
# O2_C5           300.19
# AC_level         85.85
# AC_rbk_open      98.68
# AC_valve_open   100.00
# P_H2O            27.47
# P_O2              8.40
# P_tot            31.28
# P_valve         100.00
# P_tot_2          31.28
# T_C1            233.23
# T_C2            232.48
# T_C3            232.26
# T_C4            234.02
# T_C5            230.72
# T_abg           230.02
# P_O2_in          36.11
# FT1_level       102.96
# FT1_P             7.74
# FT1_T_in        308.59
# FT1_T           174.23
# FT2_level        99.96
# FT2_P             1.14
# FT2_T           123.40
# Cond_Q           70.12
# Cond_level      103.30
# Cond_valve        7.77
# O2_conc_1       100.00
# O2_conc_2       100.00
# Fe               47.19
# Stot             33.70
# As               13.93
# Corg             71.00
# Ctot              2.15
# Fe2+             20.28
# D_S           4,200.00
# D_SL_H        1,828.00
# Fel_sum          79.95
# C_S              60.91
# Q_SL             27.36
# G_S              23.53
# G_Seq             7.15

# %%
comp = {
        'method': 'zip',
        'archive_name': 'out.csv'
    }

FILE_NAME = os.getenv("WORK_DF_NAME")

filepath = Path(f'..\\..\\{WORK_DIR}\\{FILE_NAME}{AC}.zip')

df_work.to_csv(filepath, compression=comp)
